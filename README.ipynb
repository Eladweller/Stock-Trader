# %% [markdown]
# # Using sentiment signals to improve technical analysis based stock trading
# ## Background
# <i>Technical analysis is a trading discipline employed to evaluate investments and identify trading opportunities by analyzing statistical trends gathered from trading activity, such as price movement and volume. Unlike fundamental analysts, who attempt to evaluate a security's intrinsic value, technical analysts focus on patterns of price movements, trading signals and various other analytical charting tools to evaluate a security's strength or weakness. </i>(Investopedia)
# Because of its statistical nature, using only technical analysis in trading will result in a lot of information that is available for a human trader and that may, in the future, affect the stock's value. Therefore, it is a common practice to use it along with external information as a complimentary technique.<br>
# The sentiment signals data was supplied by Prof. Ronen Feldman and was gathered by analysing periodical Earning Calls and identifing positive and negative words within these calls. By aggregation of these positive and negative occurences, its possible to have a notion of the general state of which the company is in to, hereby called "sentiment signals".
# Using both sets of tools may allow us to resemble the information available to a human trader to a Python program desinged to trade in stocks.
# ## Mission
# Our mission is to trade using technical analysis and using signal data and to see whether having extra set of information, like sentiment signals, may potentially improve the return in comparison to using only techincal analysis tools.
# ## Workplan
# In order to see whether extra information will improve our results, we first need to develop a technical analysis based strategy. Then we will add the sentiment signal data on top of the strategy and will see whether it is possible to improve the results.
# ### Trading
# For simplicity, we will use a stock by stock method and deal with each stock individually. Furthermore, we will use the signals to open and then close each position, hence, in each action we will either buy a specific stock for a sum of 100,000 USD or sell the entire holding.
#
# ### Evaluating
# We will evaluate the performance of our strategy based on the % of the succesful positions that were opened and closed. If the percentage will go up after using the signals data, it may indicate that extra information can improve against just using technical analysis.
#
# # Instructions
# In order to start the program, put the "DATA_signals.csv" into the same folder as this notebook and run all. <br><b>WARNING:</b> It may take more than 2 days.

# %% [markdown]
# ### Load Functions

# %%
import pandas as pd
import numpy as np
import quandl
from datetime import datetime
import csv
import itertools
import random
import os

# %% [markdown]
# ### Functions

# %%
''' Converts a timestamp from string to datetime.srtptime object'''
def strToTime(string): 
    return datetime.strptime(str(string),'%Y-%m-%d %H:%M:%S')

def strToTime2(string): 
    return datetime.strptime(str(string),'%Y-%m-%d')

''' Aligns all datetime.strptime objects to same hour of the day'''
def RemoveHours(string):
    return datetime.strptime(str(string)[0:10],'%Y-%m-%d')

''' given the returns of the stocks, counts how many are within the bins defined'''
def count_freq(df):
    bins=[-5,-3,0,3,5]
    previous=0
    results=[]
    for num in bins:
        current=df[df<=num].count()-previous
        previous=current
        results.append(current)
    results.append(df[df>num].count())
#     print(results)
    return results

# %% [markdown]
# ### Load Signals Data
# In order to download the daily information regarding the specific stocks that we have sentiment signals for, we will first load the signals data provided by Ronen Feldman.

# %%
signals=pd.read_csv("DATA_signals.csv")
temp=signals["Ticker"].str.split(":",expand = True)
signals["ticker"]=temp[1] 
signals["country"]=temp[0]
X=signals[(signals["country"]=="US")].dropna(subset=["cusip"]) #removing all non-US stocks
groups=X.groupby("ticker")["Date"]
signal_dates={} #getting all relevant days
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (8,9,10,13,18,26,28,38,40,47,48,49,50,53,55,59,62,72,81,82,83,84,85,91,101,102,106,107,108,109,110,111,112,113,117,118,119,124,127,131,133,152,153,156,159,167,168,169,170,171,174,175,180,184,190,195,198,199,201,207,210,215,216,219,224,225,228) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Get the distribution of returns in the periods after Earning Calls
# By looking at the distribution of returns, we can see that more companies have had positive returns then negative returns.

# %%
results=[]
for item in ["Return5 After","Return10 After","Return20 After","Return30 After","Return60 After"]:
    results.append(count_freq(signals.loc[:,item]))
print(pd.DataFrame(results, columns=["-5% and less","-5% to-3%","-3% to 0%","0% to 3%","3%-5%","5% and more"],index=[["Return5 After","Return10 After","Return20 After","Return30 After","Return60 After"]]))
# Out:
#                 -5% and less  -5% to-3%  -3% to 0%  0% to 3%  3%-5%  \
# Return5 After          27937      16927      76404     57326  91219
# Return10 After         34059      13682      66856     49343  85638
# Return20 After         40442      12289      65976     39752  81778
# Return30 After         41780      10299      62737     32836  77434
# Return60 After         48812       7615      63356     22621  73412
#
#                 5% and more
# Return5 After         25479
# Return10 After        39114
# Return20 After        51802
# Return30 After        62771
# Return60 After        76052

# %% [markdown]
# ### for all stocks get the relevant dates for the signals

# %%
signal_range={}
for (name1,start),(name2,end) in zip(groups.min().iteritems(),groups.max().iteritems()):
    signal_range[name1]={"start":strToTime(start),"end":strToTime(end)}
print("Total number of symbols: {}".format(len(signal_range.keys())))

signal_dates=groups.unique().apply(lambda x: [strToTime(i) for i in x])
signal_dates_dict=signal_dates.to_dict()
# Out:
# Total number of symbols: 7043

# %% [markdown]
# ### get the stocks data from Quandl

# %%
if os.path.isfile("quandle_wiki.csv"):
    df=pd.read_csv("quandle_wiki.csv")
    loaded=set(df["ticker"].unique())
    df["date"]=df["date"].apply(strToTime2).apply(RemoveHours)
else:             
    quandl.ApiConfig.api_key = "auaWaFEjzyKC7myZg4a-"
    loaded=set()
    not_found=set()
    data=[]
    idx=0
    for ticker,dates in signal_range.items():
        getdata = quandl.get_table('WIKI/PRICES', ticker = ticker, 
                            date = { 'gte': dates["start"]-pd.to_timedelta(1,"y"),
                                    'lte': dates["end"]+ pd.to_timedelta(3,"m")}, paginate=True)
        if getdata.shape[0]==0:
            not_found.add(ticker)
        else:
            loaded.add(ticker)
            datatemp=getdata.loc[:,["ticker","date","adj_open","adj_high","adj_low","adj_close","adj_volume"]]
            data.append(datatemp)
        idx+=1
        if idx%500==0:
            print("gone over {0}/{1} {2} symbols were loaded, {3}  not found".format(idx,len(signal_dates.keys()),len(loaded),len(not_found)))
    df=pd.concat(data,ignore_index=True).sort_values(["ticker","date"])
    df.reset_index(drop=True)
    print("gone over {0}/{1} {2} symbols were loaded, {3}  not found".format(idx,len(signal_dates.keys()),len(loaded),len(not_found)))
    df.to_csv("quandle_wiki.csv",index_label=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6432468 entries, 2947 to 6429571
# Data columns (total 7 columns):
# ticker        object
# date          datetime64[ns]
# adj_open      float64
# adj_high      float64
# adj_low       float64
# adj_close     float64
# adj_volume    float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 392.6+ MB

# %% [markdown]
# ### filter the signal data to include only stocks found in Quandl

# %%
signals_data=signals[signals["ticker"].isin(loaded)]
del signals_data["Ticker"]
del signals_data["cusip"]
del signals_data["ID"]
signals_data=signals_data.reset_index(drop=True)

# %% [markdown]
# ### Arrange the signal data to be merged and adding aggscore1 and aggscore2 to the DataFrame
# #### Aggscore1 and Aggscore2 are an aggregation of the number of positive and negative sentiment signals that are found in a single stock on a single date, extracted from Earning Calls.
# <br>$
# \begin{align}
# aggscore1 & = \frac{Positive-Negative}{Positive+Negative+1}\
# \end{align}
# $
# <br>
# <br>$
# \begin{align}
# aggscore2 & = \frac{Positive}{Positive+Negative+1}\
# \end{align}
# $<br>
#
# #### The SD scores are calculated per each aggregated score in order to measure the sentiment on a timeframe basis and ascertaining a trend in the sentiment of each company.
# -  SD is defined as the change in sentiment score from the previous period, it should reflect the short term change in the  sentiment of the stock.
# <t><br><br>$
# \begin{align}
# SD & = SentimentScore_t-SentimentScore_{t-1}
# \end{align}
# $<br><br>
# -  SD4 is defined as the average change in sentiment for the last 4 periods, at should reflect the medium term change in the sentiment of the stock.
# <t><br><br>$
# \begin{align}
# SD4 & = SentimentScore_t-\frac{SentimentScore_{t-1}+SentimentScore_{t-2}+SentimentScore_{t-3}}3\
# \end{align}
# $<br>

# %%
signals_data_small=signals_data.loc[:,["ticker","Date","Positives","Negatives"]].rename(columns={"Date":"date"}).sort_values(["date","ticker"])
signals_data_small["date"]=signals_data_small["date"].apply(RemoveHours)
signals_data_small=signals_data_small.groupby(by=["ticker","date"]).sum().reset_index(drop=False)
signals_data_small["aggscore1"]= (signals_data_small["Positives"]-signals_data_small["Negatives"])/(signals_data_small["Positives"]+signals_data_small["Negatives"]+1)
signals_data_small["aggscore2"]=(signals_data_small["Positives"])/(signals_data_small["Positives"]+signals_data_small["Negatives"]+1)

ToConcat=[]
for idx,ticker in enumerate(signals_data_small["ticker"].unique()):
#     print(ticker)
    temp=signals_data_small[signals_data_small["ticker"]==ticker].reset_index(drop=True)
    if temp.empty or temp.shape[0]<=4:
        continue
    temp=temp[4:]
    for agg in ["aggscore1","aggscore2"]:
        for i in range(1,5):
            temp["lag{}".format(i)]=temp[agg].shift(periods=i)
#         print(temp.shape)
        temp["ave4"]=temp.apply(lambda x: sum([x["lag{}".format(j)] for j in range(1,5)])/4,axis=1)
        temp["{}_SD".format(agg)]=temp[agg]-temp["lag1"]
        temp["{}_SD4".format(agg)]=temp[agg]-temp["ave4"]
        for i in range(1,5):
            del temp["lag{}".format(i)]
        del temp["ave4"]
    ToConcat.append(temp)
#     break
#     if idx%250==0:
#         print(idx)
signals_data_small=pd.concat(ToConcat,ignore_index=True)
signals_dates=signals_data_small.groupby("ticker")["date"].unique()

# %% [markdown]
# ## Merge the Quandl data with the signals data

# %%
ToConcat=[]
for idx,ticker in enumerate(signals_data_small["ticker"].unique()):
    tempS=signals_data_small[signals_data_small["ticker"]==ticker].sort_values("date").reset_index(drop=True)
    tempD=df[df["ticker"]==ticker].sort_values("date").reset_index(drop=True)
    ToConcat.append(pd.merge_asof(tempD,tempS,on="date",direction="backward"))
#     break
DATA=pd.concat(ToConcat,ignore_index=True)
del DATA["ticker_y"]
DATA=DATA.rename(columns={"ticker_x":"ticker"})

# %% [markdown]
# ## Getting the Technical Analysis indicators
# The indicators are calculated using talib library. After offline trying of most indicators in the library, 6 indicators were chosen based on relative success with random stocks:

# %% [markdown]
# ## MACD

# %%
from talib import MACDFIX

def macd(close):
    macd, macdsignal, macdhist = MACDFIX(close)
    return series_crossover(macd,macdsignal)

# %% [markdown]
# ### What is Moving Average Convergence Divergence (MACD)?
#
# Moving Average Convergence Divergence (MACD) is a trend-following momentum indicator that shows the relationship between two moving averages of a security’s price. The MACD is calculated by subtracting the 26-period Exponential Moving Average (EMA) from the 12-period EMA. The result of that calculation is the MACD line. A nine-day EMA of the MACD, called the "signal line," is then plotted on top of the MACD line, which can function as a trigger for buy and sell signals. Traders may buy the security when the MACD crosses above its signal line and sell - or short - the security when the MACD crosses below the signal line. Moving Average Convergence Divergence (MACD) indicators can be interpreted in several ways, but the more common methods are crossovers, divergences, and rapid rises/falls.
#
# MACD Line: (12-day EMA - 26-day EMA)
#
# Signal Line: 9-day EMA of MACD Line
#
# Strategy:
#
# 1) Use MACD crossover with its signal

# %% [markdown]
#  ## Aroon Oscillator

# %%
from talib import AROONOSC

def aroonosc(high, low):
    return thresholds(AROONOSC(high,low),85,-85)

# %% [markdown]
# ### What is the Aroon Oscillator
#
# An Aroon Oscillator is a trend-following indicator that uses aspects of the Aroon Indicator ("Aroon Up" and "Aroon Down") to gauge the strength of a current trend and the likelihood that it will continue. The Aroon Oscillator is calculated by subtracting Aroon Up from Aroon Down. Readings above zero indicate that an uptrend is present, while readings below zero indicate that a downtrend is present.
#
# The Aroon Oscillator is a line that can fall between -100 and 100. A high Oscillator value is an indication of an uptrend while a low Oscillator value is an indication of a downtrend.
#
# Strategy:
#
# 2) Use high and lows values of the Aroon Oscillator

# %% [markdown]
# ## Balance Of Power

# %%
from talib import BOP

def bop(Open,high,low,close):
    return thres_crossover(BOP(Open,high,low,close))

# %% [markdown]
# The Balance of Power is a simple indicator and it is used in technical analysis to compare the strength of buyers vs. sellers. The BOP oscillates around zero center line in the range from -1 to +1. Positive BOP reading is an indication of buyers' dominance and negative BOP reading is a sign of the stronger selling pressure. When BOP is equal zero it indicates that buyers and sellers are equally strong.
#
# Strategy:
#
# 3) Use the crossover of the BOP with 0.

# %% [markdown]
# ## Commodity Channel Index

# %%
from talib import CCI

def cci(high,low,close):
    return thresholds(CCI(high,low,close),100,-100)

# %% [markdown]
#  CCI measures the difference between a security's price change and its average price change. High positive readings indicate that prices are well above their average, which is a show of strength. Low negative readings indicate that prices are well below their average, which is a show of weakness.
#
# The Commodity Channel Index (CCI) can be used as either a coincident or leading indicator. As a coincident indicator, surges above +100 reflect strong price action that can signal the start of an uptrend. Plunges below -100 reflect weak price action that can signal the start of a downtrend.
#
# Strategy:
#
# 4) Use the CCI values that are above or below 100 and -100

# %% [markdown]
# ## Absolute Price Oscillator

# %%
from talib import APO

def apo(close):
    return thres_crossover(APO(close,20,50))

# %% [markdown]
# ### What is The Absolute Price Oscillator (APO)?
# The Absolute Price Oscillator displays the difference between two exponential moving averages of a security's price and is expressed as an absolute value. It rates the trends strength in relation to the moving between the two moving averages with short-term momentum being the catalyst. The most popular setups are to use the 14-day and 30-day EMAs, respectively.
#
# All signals are generated by the signal line crossing above zero-level which is considered bullish while crossing below zero-level is deemed bearish. As short-term momentum increases or decreases and eclipses long-term momentum the signal is generated. As is common with most oscillators, divergence in the stock price and indicator can also alert investors to early turnarounds.
#
# Strategy:
#
# 5) use the crossover of APO with 0

# %% [markdown]
# ## Stochastic Relative Strength Index

# %%
from talib import STOCHRSI

def stochrsi(close):
    fastk,fastd=STOCHRSI(close)
    return thresholds(fastk,80,20)

# %% [markdown]
# ### What Is the Stochastic RSI?
#
# The Stochastic RSI (StochRSI) is an indicator used in technical analysis that ranges between zero and one (or zero and 100 on some charting platforms) and is created by applying the Stochastic oscillator formula to a set of relative strength index (RSI) values rather than to standard price data. Using RSI values within the Stochastic formula gives traders an idea of whether the current RSI value is overbought or oversold.
#
# The StochRSI oscillator was developed to take advantage of both momentum indicators in order to create a more sensitive indicator that is attuned to a specific security's historical performance rather than a generalized analysis of price change.
#
# A StochRSI reading above 0.8 is considered overbought, while a reading below 0.2 is considered oversold. On the zero to 100 scale, above 80 is overbought, and below 20 is oversold.
#
# Strategy:
#
# 6) Use the STORSI values of above and below 80 and 20

# %% [markdown]
# ### Time series functions
# To extract the signals out of the technical analysis functios, we defined few functions that returns the relevant signal. If function returns 1 it means that we get a positive signal, if the function returns 0 it means that there is no relevant signal and if it return -1 it means that a negative signal was returned.

# %%
'''gets two time-series, and returns 1 every time the first series crossed-over from below the second series
and returns -1 every time the first series crossed over the second series from above'''
def series_crossover(series1,series2):
    CO=[]
    c=series1-series2
    p=series1.shift(1)-series2.shift(1)
    for current,previous in zip(c,p):
        if current>0 and previous<0:
            CO.append(1)
            continue
        if current<0 and previous>0:
            CO.append(-1)
            continue
        CO.append(0)
    return pd.Series(CO)

'''gets a series and a threshold and returns 1 if the series crossed over from below the thresholdes
and -1 if the series crossed over from above the thresholder'''
def thres_crossover(series,threshold=0):
    CO=[]
    c=series-threshold
    p=series.shift(1)-threshold
    for current,previous in zip(c,p):
        if current>0 and previous<0:
            CO.append(1)
            continue
        if current<0 and previous>0:
            CO.append(-1)
            continue
        CO.append(0)
    return pd.Series(CO)

'''gets a series and 2 thresholds and returns 1 if the series
is above the higher threshold and -1 if the series is below the lower threshold'''
def thresholds(series,higher,lower):
    time_series=[]
    for item in series:
        if item > higher:
            time_series.append(1)
            continue
        if item < lower:
            time_series.append(-1)
            continue
        time_series.append(0)
    return pd.Series(time_series)

# %% [markdown]
# ### Appying the functions on the relevant indicators and appending the results to the DataFrame

# %%
ToConcat=[]
for idx,ticker in enumerate(DATA["ticker"].unique()):
    temp=DATA[DATA["ticker"]==ticker].reset_index(drop=True)
    temp["MACD"]=macd(temp["adj_close"])
    temp["AROONOSC"]=aroonosc(temp["adj_high"],temp["adj_low"])
    temp["BOP"]=bop(temp["adj_open"],temp["adj_high"],temp["adj_low"],temp["adj_close"])
    temp["CCI"]=cci(temp["adj_high"], temp["adj_low"], temp["adj_close"])
    temp["APO"]=apo(temp["adj_close"])
    temp["STOCHRSI"]=stochrsi(temp["adj_close"])
    ToConcat.append(temp)
DATA=pd.concat(ToConcat,ignore_index=True)
DATA.to_csv("merged_data.csv", index_label=False)

# %% [markdown]
# ### Arranging the signal data
# In order to have an understanding of the sentiment signal data values, in relation to the rest of the market, we will trade based on the relative position of the signals for the specific time. therefore, we will divide the signals for 4 quartiles, and each stock will get a rating between 1 and 4 for its relative position for the specific day. Later, we will only buy stocks that are in the top quartile and sell only stocks that are in the bottom one. It means that we will not sale or buy stocks that are not in the 2nd and 3rd quartiles.

# %%
def get_quantiles(df,head,parts=4):
    subset=df.loc[:,["ticker",head]].sort_values(head,ascending=False).reset_index(drop=True).dropna()
    length=subset.shape[0]
    subset["quantiles"]=pd.qcut(subset[head],q=parts,labels=False,duplicates='drop')+1
    quantiles=subset.set_index("ticker").loc[:,["quantiles"]].to_dict()
    return quantiles["quantiles"]

ToConcat=[]
to_get_quntiles=['aggscore1','aggscore2','aggscore1_SD', 'aggscore1_SD4', 'aggscore2_SD', 'aggscore2_SD4']
for date in DATA["date"].unique():
    temp=DATA[DATA["date"]==date].reset_index(drop=True)
    for to_get in to_get_quntiles:
        quantiles=get_quantiles(temp,to_get)
        temp["Q_{}".format(to_get)]=temp["ticker"].map(quantiles)
    ToConcat.append(temp)
DATA=pd.concat(ToConcat,ignore_index=True).sort_values(["ticker","date"])
DATA.reset_index(drop=True).to_csv("merged_data.csv",index_label=False)

# %% [markdown]
# ## Trading
#
# Trading will be done per stock, and with 2 possible options per stock per day, "open position" and "closed position".

# %% [markdown]
# ### Trading functions

# %%
'''Opens a position'''
def OpenPosition(account,price,amount,date):
    AmountToBuy=amount//price
    account["Holding"]=AmountToBuy
    account["Cash"]-=price*AmountToBuy
#     print("({}) bought {} stocks at {}".format(date,AmountToBuy,price))
    return account
'''Closes a position'''
def ClosePosition(account,price,date):
#     print("({}) sold {} stocks at {}".format(date,account["Holding"],price))
    account["Cash"]+=price*account["Holding"]
    account["Holding"]=0
    return account

def geo_mean(series):
    if len(series)==0:
        return 0
    a = np.array(series)
    return a.prod()**(1.0/len(a))

'''Trades the stocks based on the parameters given to it '''
def trade(param,stock,account):
    BZ=param[0]
    BC=param[1]
    SZ=param[2]
    SC=param[3]
#     print(BZ,BC,SZ,SC)
    Position=False
    PositionsGrade=[]
    exitValue=None
    entryValue=None
    PositionsGrade=[]

    for idx,row in stock.iterrows():
        Buy=False
        Sell=False
        BuyZone = (row["AROONOSC"]==1) + (row["CCI"]==1) + (row["STOCHRSI"]==1)
        SellZone = (row["AROONOSC"]==-1) + (row["CCI"]==-1) + (row["STOCHRSI"]==-1)
        SellCrossover= (row["MACD"]==-1) + (row["BOP"]==-1) + (row["APO"]==-1)
        BuyCrossover= (row["MACD"]==1) + (row["BOP"]==1) + (row["APO"]==1)
#         print(BuyZone,BuyCrossover,SellZone,SellCrossover)
        if ((BuyZone == BZ) and (BuyCrossover==BC)) and (Position is False):
#             print("opened position at {}".format(row["adj_close"]))
#             Positions=[row["date"],row["adj_close"],row["date"],row["AROONOSC"],row["CCI"],row["STOCHRSI"],row["MACD"],row["BOP"],row["APO"]]
            account=OpenPosition(account,row["adj_close"],account["Cash"],row["date"])
            Buy=True
            Position=True
            entryValue=row["adj_close"]
        if ((SellZone ==SZ) and (SellCrossover==SC)) and (Position is True):
#             print("closed position at {}".format(row["adj_close"]))
            account=ClosePosition(account,row["adj_close"],row["date"])
            Position=False
#             Positions.extend([row["date"],row["adj_close"],row["date"],row["AROONOSC"],row["CCI"],row["STOCHRSI"],row["MACD"],row["BOP"],row["APO"]])
            Sell=True
            exitValue=row["adj_close"]
            PositionsGrade.append([entryValue,exitValue])
#     print(PositionsGrade)
    return account,PositionsGrade

'''Calculates the success rate on the positions we had'''
def SuccessRate(series):
    count=0
    length=len(series)
    if length==0:
        return 0
    for i in series:
        if i[0]<i[1]:
            count+=1
    return count/length

'''Calculates the monitary value of the holding a given stock'''
def CalcValue(account,value):
    return account["Cash"]+account["Holding"]*account["Cash"]

'''Trades when given a sentiment and parameters'''
def tradeSentiment(param,stock,account,sentiment):
#     print(param)
    BZ=param[0]
    BC=param[1]
    SZ=param[2]
    SC=param[3]
    Position=False
    PositionsGrade=[]
    exitValue=None
    entryValue=None
    PositionsGrade=[]
    for idx,row in stock.iterrows():
        close=row["adj_close"]
        if sentiment==None:
            higherSentiment=True
            lowerSentiment=True
        else:
            higherSentiment=row[sentiment]==4
            lowerSentiment=row[sentiment]==1
        Buy=False
        Sell=False
        BuyZone = (row["AROONOSC"]==1) + (row["CCI"]==1) + (row["STOCHRSI"]==1)
        SellZone = (row["AROONOSC"]==-1) + (row["CCI"]==-1) + (row["STOCHRSI"]==-1)
        SellCrossover= (row["MACD"]==-1) + (row["BOP"]==-1) + (row["APO"]==-1)
        BuyCrossover= (row["MACD"]==1) + (row["BOP"]==1) + (row["APO"]==1)
#         print(higherSentiment)
#         print(BuyZone,BuyCrossover,SellZone,SellCrossover)
        if ((BuyZone == BZ) and (BuyCrossover==BC)) and (Position is False) and (higherSentiment==True):
#             print("opened position at {}".format(row["adj_close"]))
#             Positions=[row["date"],row["adj_close"],row["date"],row["AROONOSC"],row["CCI"],row["STOCHRSI"],row["MACD"],row["BOP"],row["APO"]]
            account=OpenPosition(account,row["adj_close"],account["Cash"],row["date"])
            Buy=True
            Position=True
            entryValue=row["adj_close"]
        if (((SellZone ==SZ) and (SellCrossover==SC)) and (lowerSentiment==True)) and (Position is True):
#             print("closed position at {}".format(row["adj_close"]))
            account=ClosePosition(account,row["adj_close"],row["date"])
            Position=False
#             Positions.extend([row["date"],row["adj_close"],row["date"],row["AROONOSC"],row["CCI"],row["STOCHRSI"],row["MACD"],row["BOP"],row["APO"]])
            Sell=True
            exitValue=row["adj_close"]
            PositionsGrade.append(exitValue/entryValue)
#     print("{0:.0f}, {1:.0f}".format(CalcValue(account,row["adj_close"]),stock["adj_close"].iloc[-1]/stock["adj_close"].iloc[0]*100000))
    ratio=sum([i>1 for i in PositionsGrade])
    try:
        return CalcValue(account,row["adj_close"]),stock["adj_close"].iloc[-1]/stock["adj_close"].iloc[0]*100000,len(PositionsGrade),ratio
    except:
        return 0,0,0,0

# %% [markdown]
# ## Identifing the best parameters
# In order to get the best parameters to later by applied our model for the full dataset, we will divide the indicators into 2 groups, 'buy' and 'sell' signals, with crossovers and general zones as subgroups.
# <br><b> Buying and selling indicators:</b>
# - MACD
# - BOP
# - APO
#
# <b>Buying and selling zones</b>
# - AROONOSC
# - CCI
# - STORSI
#
# We will sum-up the Buying and selling stocks and zone seprately, and get 4 parameters that represent the 6 techical analysis indicators. Then we will try different values for the 4 parameters, ranging from 0 (no indicator is relevant) to 3 (all indicators are relevant).
# In order to find the best possible parameters, we will try all in 10 iterations, each time with 5 different random selected stocks. After that, Best performing parameters will be applied to our full model with the sentiment data.
#
# ### defining initial parameters

# %%
DATA=pd.read_csv("merged_data.csv")
stock_list=DATA["ticker"].unique().tolist()
timer=0
stocks=random.sample(stock_list,len(stock_list))

# %%
cash=100000
params_performance=[]
Performance=[]
time1=datetime.now()
DATA.sort_values(["ticker","date"])
for check in range(0,10):
    params=itertools.product([2,1,3,0],repeat=4)
    stocks=random.sample(stock_list,len(stock_list))
    for loop,param in enumerate(params,1):
        if sum(param)<2:
            continue
        FinalValues=[]
        time2=datetime.now()
        Performance=[]
        cash=100000
        Positions=[]
        for idxs,CurrentStock in enumerate(stocks):
            account={"Holding":0,"Cash":cash}
            stock=DATA[DATA["ticker"]==CurrentStock].dropna(subset=["Positives"]).sort_values("date").reset_index(drop=True)
            account,PositionsGrade=trade(param,stock,account)
            SRate=SuccessRate(PositionsGrade)
            Positions.append(len(PositionsGrade))
#             print(PositionsGrade)
#             print(len(PositionsGrade))
            try:
                Performance_temp=([CurrentStock,
                                   (CalcValue(account,stock["adj_close"].iloc[-1]))/100000,
                                   stock["adj_close"].iloc[-1]/stock["adj_close"].iloc[0],
                                    SRate,len(PositionsGrade)])
                Performance.append(Performance_temp)
                FinalValues.append(CalcValue(account,stock["adj_close"].iloc[-1]))
            except:
                pass
                print("failed")
                print(account.get("Holding"))
                print(stock["adj_close"].iloc[-1])
                print()
                      
            if idxs==5:
                break
#         print(Performance)
        results=pd.DataFrame(Performance,columns=["ticker","strategy_return","stock_return","Succssess_rate","count_positions"])
        results["ratio"]=results["strategy_return"]/results["stock_return"]
        results.to_csv("performance/{}_{} results.csv".format(check,param),index_label=False)
        print("{0})with parameters {1}, Performace: {2:.2f}, mPos:{3:.2f},SRate:{4:.2f} time:{5}, total_runtime{6}"
              .format(loop,param,geo_mean(results["ratio"]),results["count_positions"].mean(),SRate
                      ,datetime.now()-time2,datetime.now()-time1))
        if len(FinalValues)==0:
            final=0
        else:
            final=sum(FinalValues)/len(FinalValues)
        params_performance.append([check,param,geo_mean(results["ratio"]),final,sum(Positions)])
#         if loop>=1:
#             break
    performance_check=pd.DataFrame(params_performance,columns=["round","params","results","final_values","Positions"])
performance_check.to_csv("PerformanceCheck.csv",index_label=False)
# Out:
# 1)with parameters (2, 2, 2, 2), Performace: 0.71, mPos:2.33,SRate:0.67 time:0:00:11.294420, total_runtime0:00:16.645230
# 2)with parameters (2, 2, 2, 1), Performace: 0.85, mPos:5.50,SRate:0.33 time:0:00:10.952219, total_runtime0:00:27.597449
# 3)with parameters (2, 2, 2, 3), Performace: 0.37, mPos:0.00,SRate:0.00 time:0:00:10.931020, total_runtime0:00:38.528469
# 4)with parameters (2, 2, 2, 0), Performace: 0.70, mPos:6.00,SRate:0.33 time:0:00:10.812819, total_runtime0:00:49.341288
# 5)with parameters (2, 2, 1, 2), Performace: 0.63, mPos:5.50,SRate:1.00 time:0:00:10.857619, total_runtime0:01:00.198907
# 6)with parameters (2, 2, 1, 1), Performace: 0.75, mPos:6.50,SRate:1.00 time:0:00:10.857619, total_runtime0:01:11.056526
# 7)with parameters (2, 2, 1, 3), Performace: 0.37, mPos:0.00,SRate:0.00 time:0:00:10.935619, total_runtime0:01:21.992145
# 8)with parameters (2, 2, 1, 0), Performace: 0.79, mPos:6.33,SRate:1.00 time:0:00:10.795219, total_runtime0:01:32.787364
# 9)with parameters (2, 2, 3, 2), Performace: 0.42, mPos:1.17,SRate:1.00 time:0:00:10.842019, total_runtime0:01:43.629383
# 10)with parameters (2, 2, 3, 1), Performace: 0.52, mPos:4.17,SRate:0.67 time:0:00:10.795219, total_runtime0:01:54.424602
# 11)with parameters (2, 2, 3, 3), Performace: 0.37, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:02:05.235421
# 12)with parameters (2, 2, 3, 0), Performace: 0.75, mPos:5.33,SRate:0.67 time:0:00:10.842019, total_runtime0:02:16.077440
# 13)with parameters (2, 2, 0, 2), Performace: 0.55, mPos:3.00,SRate:1.00 time:0:00:10.799219, total_runtime0:02:26.876659
# 14)with parameters (2, 2, 0, 1), Performace: 0.78, mPos:6.50,SRate:1.00 time:0:00:10.843019, total_runtime0:02:37.719678
# 15)with parameters (2, 2, 0, 3), Performace: 0.37, mPos:0.00,SRate:0.00 time:0:00:10.732819, total_runtime0:02:48.452497
# 16)with parameters (2, 2, 0, 0), Performace: 0.79, mPos:6.67,SRate:0.00 time:0:00:10.764019, total_runtime0:02:59.216516
# 17)with parameters (2, 1, 2, 2), Performace: 0.25, mPos:5.00,SRate:0.38 time:0:00:10.781619, total_runtime0:03:09.998135
# 18)with parameters (2, 1, 2, 1), Performace: 0.54, mPos:27.00,SRate:0.48 time:0:00:10.920019, total_runtime0:03:20.918154
# 19)with parameters (2, 1, 2, 3), Performace: 0.11, mPos:0.00,SRate:0.00 time:0:00:10.734819, total_runtime0:03:31.652973
# 20)with parameters (2, 1, 2, 0), Performace: 0.46, mPos:40.17,SRate:0.38 time:0:00:10.904419, total_runtime0:03:42.557392
# 21)with parameters (2, 1, 1, 2), Performace: 0.57, mPos:15.00,SRate:0.60 time:0:00:10.857620, total_runtime0:03:53.415012
# 22)with parameters (2, 1, 1, 1), Performace: 0.51, mPos:55.17,SRate:0.32 time:0:00:10.842019, total_runtime0:04:04.257031
# 23)with parameters (2, 1, 1, 3), Performace: 0.11, mPos:0.00,SRate:0.00 time:0:00:10.826419, total_runtime0:04:15.083450
# 24)with parameters (2, 1, 1, 0), Performace: 0.66, mPos:55.67,SRate:0.51 time:0:00:10.826419, total_runtime0:04:25.925469
# 25)with parameters (2, 1, 3, 2), Performace: 0.42, mPos:2.00,SRate:0.25 time:0:00:10.779619, total_runtime0:04:36.705088
# 26)with parameters (2, 1, 3, 1), Performace: 0.19, mPos:14.50,SRate:0.39 time:0:00:10.842019, total_runtime0:04:47.547107
# 27)with parameters (2, 1, 3, 3), Performace: 0.11, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:04:58.326726
# 28)with parameters (2, 1, 3, 0), Performace: 0.55, mPos:23.17,SRate:0.50 time:0:00:10.748418, total_runtime0:05:09.075144
# 29)with parameters (2, 1, 0, 2), Performace: 0.77, mPos:6.00,SRate:0.57 time:0:00:10.951220, total_runtime0:05:20.026364
# 30)with parameters (2, 1, 0, 1), Performace: 0.86, mPos:70.83,SRate:0.43 time:0:00:10.873219, total_runtime0:05:30.899583
# 31)with parameters (2, 1, 0, 3), Performace: 0.11, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:05:41.679202
# 32)with parameters (2, 1, 0, 0), Performace: 0.84, mPos:76.17,SRate:0.04 time:0:00:10.904419, total_runtime0:05:52.583621
# 33)with parameters (2, 3, 2, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:06:03.378840
# 34)with parameters (2, 3, 2, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.732819, total_runtime0:06:14.111659
# 35)with parameters (2, 3, 2, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.842019, total_runtime0:06:24.953678
# 36)with parameters (2, 3, 2, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.732819, total_runtime0:06:35.686497
# 37)with parameters (2, 3, 1, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.861619, total_runtime0:06:46.548116
# 38)with parameters (2, 3, 1, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:06:57.358935
# 39)with parameters (2, 3, 1, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.732819, total_runtime0:07:08.091754
# 40)with parameters (2, 3, 1, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:07:18.886973
# 41)with parameters (2, 3, 3, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.904419, total_runtime0:07:29.791392
# 42)with parameters (2, 3, 3, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:07:40.539811
# 43)with parameters (2, 3, 3, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.749419, total_runtime0:07:51.289230
# 44)with parameters (2, 3, 3, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:08:02.100049
# 45)with parameters (2, 3, 0, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:08:12.879668
# 46)with parameters (2, 3, 0, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779618, total_runtime0:08:23.659286
# 47)with parameters (2, 3, 0, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.826419, total_runtime0:08:34.485705
# 48)with parameters (2, 3, 0, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.717219, total_runtime0:08:45.202924
# 49)with parameters (2, 0, 2, 2), Performace: 0.40, mPos:5.00,SRate:0.38 time:0:00:10.764019, total_runtime0:08:55.966943
# 50)with parameters (2, 0, 2, 1), Performace: 0.49, mPos:32.83,SRate:0.46 time:0:00:10.826419, total_runtime0:09:06.793362
# 51)with parameters (2, 0, 2, 3), Performace: 0.35, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:09:17.541781
# 52)with parameters (2, 0, 2, 0), Performace: 0.31, mPos:49.00,SRate:0.42 time:0:00:11.013619, total_runtime0:09:28.555400
# 53)with parameters (2, 0, 1, 2), Performace: 0.76, mPos:16.50,SRate:0.69 time:0:00:10.888820, total_runtime0:09:39.444220
# 54)with parameters (2, 0, 1, 1), Performace: 1.01, mPos:79.50,SRate:0.42 time:0:00:10.826419, total_runtime0:09:50.270639
# 55)with parameters (2, 0, 1, 3), Performace: 0.35, mPos:0.00,SRate:0.00 time:0:00:10.827419, total_runtime0:10:01.098058
# 56)with parameters (2, 0, 1, 0), Performace: 0.95, mPos:84.67,SRate:0.47 time:0:00:10.875021, total_runtime0:10:11.973079
# 57)with parameters (2, 0, 3, 2), Performace: 0.69, mPos:2.00,SRate:0.25 time:0:00:10.810819, total_runtime0:10:22.783898
# 58)with parameters (2, 0, 3, 1), Performace: 0.35, mPos:15.83,SRate:0.38 time:0:00:10.795219, total_runtime0:10:33.579117
# 59)with parameters (2, 0, 3, 3), Performace: 0.35, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:10:44.389936
# 60)with parameters (2, 0, 3, 0), Performace: 0.47, mPos:25.67,SRate:0.46 time:0:00:10.810819, total_runtime0:10:55.200755
# 61)with parameters (2, 0, 0, 2), Performace: 0.78, mPos:6.33,SRate:0.57 time:0:00:10.843019, total_runtime0:11:06.043774
# 62)with parameters (2, 0, 0, 1), Performace: 1.03, mPos:114.67,SRate:0.36 time:0:00:10.873219, total_runtime0:11:16.916993
# 63)with parameters (2, 0, 0, 3), Performace: 0.35, mPos:0.00,SRate:0.00 time:0:00:10.873219, total_runtime0:11:27.790212
# 64)with parameters (2, 0, 0, 0), Performace: 0.85, mPos:212.50,SRate:0.22 time:0:00:10.935619, total_runtime0:11:38.725831
# 65)with parameters (1, 2, 2, 2), Performace: 0.59, mPos:4.00,SRate:0.50 time:0:00:10.810819, total_runtime0:11:49.536650
# 66)with parameters (1, 2, 2, 1), Performace: 0.56, mPos:12.50,SRate:0.21 time:0:00:10.795219, total_runtime0:12:00.331869
# 67)with parameters (1, 2, 2, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:10.873219, total_runtime0:12:11.205088
# 68)with parameters (1, 2, 2, 0), Performace: 0.60, mPos:14.17,SRate:0.31 time:0:00:10.873219, total_runtime0:12:22.078307
# 69)with parameters (1, 2, 1, 2), Performace: 0.47, mPos:8.50,SRate:0.67 time:0:00:10.951219, total_runtime0:12:33.029526
# 70)with parameters (1, 2, 1, 1), Performace: 0.78, mPos:14.50,SRate:0.31 time:0:00:10.920020, total_runtime0:12:43.949546
# 71)with parameters (1, 2, 1, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:10.842019, total_runtime0:12:54.791565
# 72)with parameters (1, 2, 1, 0), Performace: 0.66, mPos:14.83,SRate:0.25 time:0:00:10.779619, total_runtime0:13:05.571184
# 73)with parameters (1, 2, 3, 2), Performace: 0.72, mPos:1.83,SRate:0.33 time:0:00:10.888819, total_runtime0:13:16.460003
# 74)with parameters (1, 2, 3, 1), Performace: 0.35, mPos:9.17,SRate:0.33 time:0:00:10.920019, total_runtime0:13:27.380022
# 75)with parameters (1, 2, 3, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:10.717219, total_runtime0:13:38.097241
# 76)with parameters (1, 2, 3, 0), Performace: 0.41, mPos:12.17,SRate:0.38 time:0:00:10.764019, total_runtime0:13:48.861260
# 77)with parameters (1, 2, 0, 2), Performace: 0.59, mPos:4.50,SRate:0.80 time:0:00:10.779619, total_runtime0:13:59.640879
# 78)with parameters (1, 2, 0, 1), Performace: 0.68, mPos:15.00,SRate:0.38 time:0:00:10.737819, total_runtime0:14:10.378698
# 79)with parameters (1, 2, 0, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:10.732819, total_runtime0:14:21.111517
# 80)with parameters (1, 2, 0, 0), Performace: 0.78, mPos:15.50,SRate:0.00 time:0:00:10.764018, total_runtime0:14:31.875535
# 81)with parameters (1, 1, 2, 2), Performace: 0.37, mPos:5.67,SRate:0.62 time:0:00:10.732819, total_runtime0:14:42.608354
# 82)with parameters (1, 1, 2, 1), Performace: 0.71, mPos:44.50,SRate:0.49 time:0:00:10.779619, total_runtime0:14:53.387973
# 83)with parameters (1, 1, 2, 3), Performace: 0.42, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:15:04.167592
# 84)with parameters (1, 1, 2, 0), Performace: 0.28, mPos:73.67,SRate:0.34 time:0:00:10.810819, total_runtime0:15:14.978411
# 85)with parameters (1, 1, 1, 2), Performace: 0.59, mPos:16.17,SRate:0.80 time:0:00:10.889819, total_runtime0:15:25.868230
# 86)with parameters (1, 1, 1, 1), Performace: 0.31, mPos:104.83,SRate:0.44 time:0:00:10.873219, total_runtime0:15:36.741449
# 87)with parameters (1, 1, 1, 3), Performace: 0.42, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:15:47.489868
# 88)with parameters (1, 1, 1, 0), Performace: 0.36, mPos:121.83,SRate:0.34 time:0:00:10.920019, total_runtime0:15:58.409887
# 89)with parameters (1, 1, 3, 2), Performace: 0.38, mPos:2.17,SRate:0.25 time:0:00:10.810819, total_runtime0:16:09.220706
# 90)with parameters (1, 1, 3, 1), Performace: 0.45, mPos:19.17,SRate:0.42 time:0:00:10.748419, total_runtime0:16:19.969125
# 91)with parameters (1, 1, 3, 3), Performace: 0.42, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:16:30.779944
# 92)with parameters (1, 1, 3, 0), Performace: 0.20, mPos:37.17,SRate:0.43 time:0:00:10.779619, total_runtime0:16:41.559563
# 93)with parameters (1, 1, 0, 2), Performace: 0.83, mPos:6.50,SRate:0.67 time:0:00:10.764019, total_runtime0:16:52.323582
# 94)with parameters (1, 1, 0, 1), Performace: 0.29, mPos:143.17,SRate:0.47 time:0:00:10.904419, total_runtime0:17:03.228001
# 95)with parameters (1, 1, 0, 3), Performace: 0.42, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:17:14.007620
# 96)with parameters (1, 1, 0, 0), Performace: 0.86, mPos:181.50,SRate:0.17 time:0:00:10.935619, total_runtime0:17:24.943239
# 97)with parameters (1, 3, 2, 2), Performace: 0.75, mPos:0.17,SRate:0.00 time:0:00:10.904420, total_runtime0:17:35.847659
# 98)with parameters (1, 3, 2, 1), Performace: 0.79, mPos:0.17,SRate:0.00 time:0:00:11.388020, total_runtime0:17:47.235679
# 99)with parameters (1, 3, 2, 3), Performace: 0.69, mPos:0.00,SRate:0.00 time:0:00:10.701618, total_runtime0:17:57.937297
# 100)with parameters (1, 3, 2, 0), Performace: 0.79, mPos:0.17,SRate:0.00 time:0:00:10.795219, total_runtime0:18:08.732516
# 101)with parameters (1, 3, 1, 2), Performace: 0.74, mPos:0.17,SRate:0.00 time:0:00:10.779619, total_runtime0:18:19.512135
# 102)with parameters (1, 3, 1, 1), Performace: 0.79, mPos:0.17,SRate:0.00 time:0:00:10.764019, total_runtime0:18:30.276154
# 103)with parameters (1, 3, 1, 3), Performace: 0.69, mPos:0.00,SRate:0.00 time:0:00:10.842019, total_runtime0:18:41.118173
# 104)with parameters (1, 3, 1, 0), Performace: 0.79, mPos:0.17,SRate:0.00 time:0:00:10.826419, total_runtime0:18:51.944592
# 105)with parameters (1, 3, 3, 2), Performace: 0.69, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:19:02.693011
# 106)with parameters (1, 3, 3, 1), Performace: 0.77, mPos:0.17,SRate:0.00 time:0:00:10.779619, total_runtime0:19:13.472630
# 107)with parameters (1, 3, 3, 3), Performace: 0.69, mPos:0.00,SRate:0.00 time:0:00:10.888819, total_runtime0:19:24.361449
# 108)with parameters (1, 3, 3, 0), Performace: 0.79, mPos:0.17,SRate:0.00 time:0:00:10.764019, total_runtime0:19:35.125468
# 109)with parameters (1, 3, 0, 2), Performace: 0.79, mPos:0.17,SRate:0.00 time:0:00:10.764019, total_runtime0:19:45.889487
# 110)with parameters (1, 3, 0, 1), Performace: 0.78, mPos:0.17,SRate:0.00 time:0:00:10.764019, total_runtime0:19:56.653506
# 111)with parameters (1, 3, 0, 3), Performace: 0.69, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:20:07.401925
# 112)with parameters (1, 3, 0, 0), Performace: 0.78, mPos:0.17,SRate:0.00 time:0:00:10.826419, total_runtime0:20:18.228344
# 113)with parameters (1, 0, 2, 2), Performace: 0.47, mPos:5.67,SRate:0.50 time:0:00:10.826419, total_runtime0:20:29.054763
# 114)with parameters (1, 0, 2, 1), Performace: 0.43, mPos:45.33,SRate:0.45 time:0:00:10.795219, total_runtime0:20:39.849982
# 115)with parameters (1, 0, 2, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.826419, total_runtime0:20:50.676401
# 116)with parameters (1, 0, 2, 0), Performace: 0.19, mPos:83.17,SRate:0.35 time:0:00:10.922019, total_runtime0:21:01.598420
# 117)with parameters (1, 0, 1, 2), Performace: 0.49, mPos:17.17,SRate:0.75 time:0:00:10.748419, total_runtime0:21:12.346839
# 118)with parameters (1, 0, 1, 1), Performace: 0.46, mPos:128.50,SRate:0.42 time:0:00:10.982419, total_runtime0:21:23.329258
# 119)with parameters (1, 0, 1, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:21:34.077677
# 120)with parameters (1, 0, 1, 0), Performace: 0.52, mPos:173.00,SRate:0.33 time:0:00:10.966819, total_runtime0:21:45.044496
# 121)with parameters (1, 0, 3, 2), Performace: 0.39, mPos:2.00,SRate:0.25 time:0:00:10.810819, total_runtime0:21:55.855315
# 122)with parameters (1, 0, 3, 1), Performace: 0.32, mPos:18.67,SRate:0.28 time:0:00:10.795219, total_runtime0:22:06.650534
# 123)with parameters (1, 0, 3, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.749419, total_runtime0:22:17.399953
# 124)with parameters (1, 0, 3, 0), Performace: 0.22, mPos:39.00,SRate:0.33 time:0:00:10.748419, total_runtime0:22:28.148372
# 125)with parameters (1, 0, 0, 2), Performace: 1.16, mPos:6.67,SRate:0.71 time:0:00:10.748419, total_runtime0:22:38.896791
# 126)with parameters (1, 0, 0, 1), Performace: 0.59, mPos:193.00,SRate:0.38 time:0:00:10.888819, total_runtime0:22:49.785610
# 127)with parameters (1, 0, 0, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:23:00.565229
# 129)with parameters (3, 2, 2, 2), Performace: 0.50, mPos:1.50,SRate:0.50 time:0:00:10.857619, total_runtime0:23:11.422848
# 130)with parameters (3, 2, 2, 1), Performace: 0.80, mPos:2.17,SRate:0.50 time:0:00:10.935619, total_runtime0:23:22.358467
# 131)with parameters (3, 2, 2, 3), Performace: 0.54, mPos:0.00,SRate:0.00 time:0:00:10.717219, total_runtime0:23:33.075686
# 132)with parameters (3, 2, 2, 0), Performace: 0.67, mPos:2.17,SRate:0.50 time:0:00:10.826419, total_runtime0:23:43.902105
# 133)with parameters (3, 2, 1, 2), Performace: 0.72, mPos:2.17,SRate:1.00 time:0:00:10.810819, total_runtime0:23:54.712924
# 134)with parameters (3, 2, 1, 1), Performace: 0.83, mPos:2.33,SRate:1.00 time:0:00:10.764019, total_runtime0:24:05.476943
# 135)with parameters (3, 2, 1, 3), Performace: 0.54, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:24:16.256562
# 136)with parameters (3, 2, 1, 0), Performace: 0.71, mPos:2.17,SRate:0.50 time:0:00:10.764019, total_runtime0:24:27.020581
# 137)with parameters (3, 2, 3, 2), Performace: 1.17, mPos:0.67,SRate:1.00 time:0:00:10.764019, total_runtime0:24:37.784600
# 138)with parameters (3, 2, 3, 1), Performace: 0.87, mPos:1.67,SRate:0.50 time:0:00:10.764019, total_runtime0:24:48.548619
# 139)with parameters (3, 2, 3, 3), Performace: 0.54, mPos:0.00,SRate:0.00 time:0:00:10.764019, total_runtime0:24:59.312638
# 140)with parameters (3, 2, 3, 0), Performace: 0.57, mPos:1.83,SRate:0.50 time:0:00:10.779619, total_runtime0:25:10.092257
# 141)with parameters (3, 2, 0, 2), Performace: 0.68, mPos:1.33,SRate:0.50 time:0:00:10.966819, total_runtime0:25:21.059076
# 142)with parameters (3, 2, 0, 1), Performace: 0.81, mPos:2.33,SRate:1.00 time:0:00:10.764019, total_runtime0:25:31.823095
# 143)with parameters (3, 2, 0, 3), Performace: 0.54, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:25:42.602714
# 144)with parameters (3, 2, 0, 0), Performace: 0.78, mPos:2.33,SRate:0.00 time:0:00:10.764019, total_runtime0:25:53.366733
# 145)with parameters (3, 1, 2, 2), Performace: 0.76, mPos:4.50,SRate:0.38 time:0:00:10.826419, total_runtime0:26:04.193152
# 146)with parameters (3, 1, 2, 1), Performace: 0.49, mPos:16.17,SRate:0.18 time:0:00:10.748419, total_runtime0:26:14.941571
# 147)with parameters (3, 1, 2, 3), Performace: 0.15, mPos:0.00,SRate:0.00 time:0:00:10.810818, total_runtime0:26:25.752389
# 148)with parameters (3, 1, 2, 0), Performace: 0.69, mPos:20.00,SRate:0.21 time:0:00:10.748419, total_runtime0:26:36.500808
# 149)with parameters (3, 1, 1, 2), Performace: 0.74, mPos:11.67,SRate:0.57 time:0:00:10.748419, total_runtime0:26:47.249227
# 150)with parameters (3, 1, 1, 1), Performace: 0.99, mPos:28.33,SRate:0.46 time:0:00:10.779619, total_runtime0:26:58.028846
# 151)with parameters (3, 1, 1, 3), Performace: 0.15, mPos:0.00,SRate:0.00 time:0:00:10.764019, total_runtime0:27:08.792865
# 152)with parameters (3, 1, 1, 0), Performace: 0.71, mPos:27.83,SRate:0.46 time:0:00:10.951219, total_runtime0:27:19.744084
# 153)with parameters (3, 1, 3, 2), Performace: 0.50, mPos:1.67,SRate:0.33 time:0:00:10.857619, total_runtime0:27:30.601703
# 154)with parameters (3, 1, 3, 1), Performace: 0.47, mPos:10.83,SRate:0.33 time:0:00:10.779619, total_runtime0:27:41.381322
# 155)with parameters (3, 1, 3, 3), Performace: 0.15, mPos:0.00,SRate:0.00 time:0:00:10.732819, total_runtime0:27:52.114141
# 156)with parameters (3, 1, 3, 0), Performace: 0.82, mPos:13.67,SRate:0.46 time:0:00:10.764019, total_runtime0:28:02.878160
# 157)with parameters (3, 1, 0, 2), Performace: 1.04, mPos:4.50,SRate:0.50 time:0:00:10.748419, total_runtime0:28:13.626579
# 158)with parameters (3, 1, 0, 1), Performace: 0.92, mPos:32.67,SRate:0.50 time:0:00:11.185220, total_runtime0:28:24.811799
# 159)with parameters (3, 1, 0, 3), Performace: 0.15, mPos:0.00,SRate:0.00 time:0:00:10.764019, total_runtime0:28:35.575818
# 160)with parameters (3, 1, 0, 0), Performace: 0.77, mPos:36.17,SRate:0.00 time:0:00:10.842019, total_runtime0:28:46.417837
# 161)with parameters (3, 3, 2, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.826419, total_runtime0:28:57.244256
# 162)with parameters (3, 3, 2, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:29:08.023875
# 163)with parameters (3, 3, 2, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.810818, total_runtime0:29:18.834693
# 164)with parameters (3, 3, 2, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.857620, total_runtime0:29:29.692313
# 165)with parameters (3, 3, 1, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779618, total_runtime0:29:40.471931
# 166)with parameters (3, 3, 1, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.764019, total_runtime0:29:51.235950
# 167)with parameters (3, 3, 1, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:30:01.984369
# 168)with parameters (3, 3, 1, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.842019, total_runtime0:30:12.826388
# 169)with parameters (3, 3, 3, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:30:23.574807
# 170)with parameters (3, 3, 3, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.720219, total_runtime0:30:34.295026
# 171)with parameters (3, 3, 3, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.874219, total_runtime0:30:45.169245
# 172)with parameters (3, 3, 3, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:30:55.948864
# 173)with parameters (3, 3, 0, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:31:06.759683
# 174)with parameters (3, 3, 0, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:11.060420, total_runtime0:31:17.820103
# 175)with parameters (3, 3, 0, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.904419, total_runtime0:31:28.724522
# 176)with parameters (3, 3, 0, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.764019, total_runtime0:31:39.488541
# 177)with parameters (3, 0, 2, 2), Performace: 0.21, mPos:4.50,SRate:0.38 time:0:00:10.654818, total_runtime0:31:50.143359
# 178)with parameters (3, 0, 2, 1), Performace: 0.48, mPos:22.83,SRate:0.33 time:0:00:10.780619, total_runtime0:32:00.923978
# 179)with parameters (3, 0, 2, 3), Performace: 0.40, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:32:11.672397
# 180)with parameters (3, 0, 2, 0), Performace: 0.44, mPos:31.17,SRate:0.26 time:0:00:10.810819, total_runtime0:32:22.483216
# 181)with parameters (3, 0, 1, 2), Performace: 0.37, mPos:14.50,SRate:0.67 time:0:00:10.857619, total_runtime0:32:33.340835
# 182)with parameters (3, 0, 1, 1), Performace: 0.73, mPos:46.00,SRate:0.48 time:0:00:10.842019, total_runtime0:32:44.182854
# 183)with parameters (3, 0, 1, 3), Performace: 0.40, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:32:54.962473
# 184)with parameters (3, 0, 1, 0), Performace: 0.69, mPos:47.83,SRate:0.40 time:0:00:10.779619, total_runtime0:33:05.742092
# 185)with parameters (3, 0, 3, 2), Performace: 0.43, mPos:2.00,SRate:0.25 time:0:00:10.811819, total_runtime0:33:16.569511
# 186)with parameters (3, 0, 3, 1), Performace: 0.24, mPos:13.67,SRate:0.33 time:0:00:11.000020, total_runtime0:33:27.569531
# 187)with parameters (3, 0, 3, 3), Performace: 0.40, mPos:0.00,SRate:0.00 time:0:00:10.764019, total_runtime0:33:38.333550
# 188)with parameters (3, 0, 3, 0), Performace: 0.67, mPos:19.17,SRate:0.41 time:0:00:10.748419, total_runtime0:33:49.081969
# 189)with parameters (3, 0, 0, 2), Performace: 0.98, mPos:5.83,SRate:0.50 time:0:00:10.810819, total_runtime0:33:59.892788
# 190)with parameters (3, 0, 0, 1), Performace: 0.84, mPos:55.33,SRate:0.36 time:0:00:10.779619, total_runtime0:34:10.672407
# 191)with parameters (3, 0, 0, 3), Performace: 0.40, mPos:0.00,SRate:0.00 time:0:00:10.748418, total_runtime0:34:21.420825
# 192)with parameters (3, 0, 0, 0), Performace: 0.76, mPos:111.17,SRate:0.08 time:0:00:10.873220, total_runtime0:34:32.309645
# 193)with parameters (0, 2, 2, 2), Performace: 0.77, mPos:2.67,SRate:0.33 time:0:00:10.842019, total_runtime0:34:43.151664
# 194)with parameters (0, 2, 2, 1), Performace: 0.68, mPos:4.83,SRate:0.33 time:0:00:10.764018, total_runtime0:34:53.915682
# 195)with parameters (0, 2, 2, 3), Performace: 0.32, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:35:04.710901
# 196)with parameters (0, 2, 2, 0), Performace: 0.68, mPos:5.33,SRate:0.50 time:0:00:10.764019, total_runtime0:35:15.474920
# 197)with parameters (0, 2, 1, 2), Performace: 0.61, mPos:5.17,SRate:0.67 time:0:00:10.862620, total_runtime0:35:26.337540
# 198)with parameters (0, 2, 1, 1), Performace: 0.74, mPos:5.50,SRate:0.57 time:0:00:10.780619, total_runtime0:35:37.118159
# 199)with parameters (0, 2, 1, 3), Performace: 0.32, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:35:47.866578
# 200)with parameters (0, 2, 1, 0), Performace: 0.70, mPos:5.33,SRate:0.57 time:0:00:10.812819, total_runtime0:35:58.679397
# 201)with parameters (0, 2, 3, 2), Performace: 0.83, mPos:1.67,SRate:0.33 time:0:00:10.861619, total_runtime0:36:09.541016
# 202)with parameters (0, 2, 3, 1), Performace: 0.51, mPos:4.67,SRate:0.60 time:0:00:10.701619, total_runtime0:36:20.242635
# 203)with parameters (0, 2, 3, 3), Performace: 0.32, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:36:31.037854
# 204)with parameters (0, 2, 3, 0), Performace: 0.57, mPos:5.17,SRate:0.67 time:0:00:10.844019, total_runtime0:36:41.881873
# 205)with parameters (0, 2, 0, 2), Performace: 0.99, mPos:2.67,SRate:0.67 time:0:00:10.764019, total_runtime0:36:52.645892
# 206)with parameters (0, 2, 0, 1), Performace: 0.74, mPos:5.33,SRate:0.57 time:0:00:10.795219, total_runtime0:37:03.441111
# 207)with parameters (0, 2, 0, 3), Performace: 0.32, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:37:14.251930
# 208)with parameters (0, 2, 0, 0), Performace: 0.75, mPos:5.50,SRate:0.00 time:0:00:10.855020, total_runtime0:37:25.106950
# 209)with parameters (0, 1, 2, 2), Performace: 0.21, mPos:5.67,SRate:0.50 time:0:00:10.764018, total_runtime0:37:35.870968
# 210)with parameters (0, 1, 2, 1), Performace: 0.21, mPos:52.83,SRate:0.32 time:0:00:10.873220, total_runtime0:37:46.744188
# 211)with parameters (0, 1, 2, 3), Performace: 0.26, mPos:0.00,SRate:0.00 time:0:00:10.748418, total_runtime0:37:57.492606
# 212)with parameters (0, 1, 2, 0), Performace: 0.33, mPos:108.50,SRate:0.20 time:0:00:10.779619, total_runtime0:38:08.272225
# 213)with parameters (0, 1, 1, 2), Performace: 0.47, mPos:17.50,SRate:0.77 time:0:00:10.795219, total_runtime0:38:19.067444
# 214)with parameters (0, 1, 1, 1), Performace: 0.40, mPos:149.83,SRate:0.41 time:0:00:10.842019, total_runtime0:38:29.909463
# 215)with parameters (0, 1, 1, 3), Performace: 0.26, mPos:0.00,SRate:0.00 time:0:00:10.783620, total_runtime0:38:40.693083
# 216)with parameters (0, 1, 1, 0), Performace: 0.41, mPos:186.83,SRate:0.24 time:0:00:10.905419, total_runtime0:38:51.598502
# 217)with parameters (0, 1, 3, 2), Performace: 0.29, mPos:2.17,SRate:0.25 time:0:00:10.748419, total_runtime0:39:02.346921
# 218)with parameters (0, 1, 3, 1), Performace: 0.24, mPos:21.33,SRate:0.27 time:0:00:10.732818, total_runtime0:39:13.079739
# 219)with parameters (0, 1, 3, 3), Performace: 0.26, mPos:0.00,SRate:0.00 time:0:00:10.921020, total_runtime0:39:24.000759
# 220)with parameters (0, 1, 3, 0), Performace: 0.32, mPos:44.00,SRate:0.22 time:0:00:10.795219, total_runtime0:39:34.795978
# 221)with parameters (0, 1, 0, 2), Performace: 0.89, mPos:6.67,SRate:0.71 time:0:00:10.748419, total_runtime0:39:45.544397
# 222)with parameters (0, 1, 0, 1), Performace: 0.75, mPos:164.67,SRate:0.52 time:0:00:10.935619, total_runtime0:39:56.480016
# 223)with parameters (0, 1, 0, 3), Performace: 0.26, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:40:07.275235
# 225)with parameters (0, 3, 2, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.780619, total_runtime0:40:18.055854
# 226)with parameters (0, 3, 2, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.888819, total_runtime0:40:28.944673
# 227)with parameters (0, 3, 2, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:40:39.724292
# 228)with parameters (0, 3, 2, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.810819, total_runtime0:40:50.535111
# 229)with parameters (0, 3, 1, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.873219, total_runtime0:41:01.408330
# 230)with parameters (0, 3, 1, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.765019, total_runtime0:41:12.173349
# 231)with parameters (0, 3, 1, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.818819, total_runtime0:41:22.992168
# 232)with parameters (0, 3, 1, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.857619, total_runtime0:41:33.849787
# 233)with parameters (0, 3, 3, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:41:44.645006
# 234)with parameters (0, 3, 3, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:41:55.424625
# 235)with parameters (0, 3, 3, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.826419, total_runtime0:42:06.251044
# 236)with parameters (0, 3, 3, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.857619, total_runtime0:42:17.108663
# 237)with parameters (0, 3, 0, 2), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.842019, total_runtime0:42:27.950682
# 238)with parameters (0, 3, 0, 1), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:42:38.699101
# 239)with parameters (0, 3, 0, 3), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.842019, total_runtime0:42:49.541120
# 240)with parameters (0, 3, 0, 0), Performace: 0.78, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:43:00.336339
# 241)with parameters (0, 0, 2, 2), Performace: 0.24, mPos:5.83,SRate:0.38 time:0:00:10.748419, total_runtime0:43:11.084758
# 242)with parameters (0, 0, 2, 1), Performace: 0.38, mPos:58.33,SRate:0.36 time:0:00:10.935619, total_runtime0:43:22.020377
# 243)with parameters (0, 0, 2, 3), Performace: 0.27, mPos:0.00,SRate:0.00 time:0:00:10.748419, total_runtime0:43:32.768796
# 244)with parameters (0, 0, 2, 0), Performace: 0.44, mPos:163.83,SRate:0.21 time:0:00:10.982419, total_runtime0:43:43.751215
# 245)with parameters (0, 0, 1, 2), Performace: 0.70, mPos:17.50,SRate:0.69 time:0:00:10.701619, total_runtime0:43:54.452834
# 246)with parameters (0, 0, 1, 1), Performace: 0.35, mPos:196.83,SRate:0.39 time:0:00:10.966820, total_runtime0:44:05.419654
# 247)with parameters (0, 0, 1, 3), Performace: 0.27, mPos:0.00,SRate:0.00 time:0:00:10.811819, total_runtime0:44:16.231473
# 249)with parameters (0, 0, 3, 2), Performace: 0.44, mPos:2.17,SRate:0.25 time:0:00:10.732818, total_runtime0:44:26.979891
# 250)with parameters (0, 0, 3, 1), Performace: 0.27, mPos:23.00,SRate:0.27 time:0:00:10.796219, total_runtime0:44:37.776110
# 251)with parameters (0, 0, 3, 3), Performace: 0.27, mPos:0.00,SRate:0.00 time:0:00:10.795219, total_runtime0:44:48.571329
# 252)with parameters (0, 0, 3, 0), Performace: 0.39, mPos:73.83,SRate:0.14 time:0:00:10.795219, total_runtime0:44:59.366548
# 253)with parameters (0, 0, 0, 2), Performace: 1.27, mPos:6.83,SRate:0.71 time:0:00:10.732819, total_runtime0:45:10.099367
# 255)with parameters (0, 0, 0, 3), Performace: 0.27, mPos:0.00,SRate:0.00 time:0:00:11.004020, total_runtime0:45:21.103387
# 1)with parameters (2, 2, 2, 2), Performace: 0.80, mPos:3.33,SRate:0.50 time:0:00:10.608019, total_runtime0:45:31.727006
# 2)with parameters (2, 2, 2, 1), Performace: 0.93, mPos:6.00,SRate:0.50 time:0:00:10.483218, total_runtime0:45:42.210224
# 3)with parameters (2, 2, 2, 3), Performace: 0.14, mPos:0.00,SRate:0.00 time:0:00:10.579819, total_runtime0:45:52.790043
# 4)with parameters (2, 2, 2, 0), Performace: 0.88, mPos:6.33,SRate:0.38 time:0:00:10.594418, total_runtime0:46:03.384461
# 5)with parameters (2, 2, 1, 2), Performace: 0.73, mPos:4.50,SRate:0.50 time:0:00:10.561219, total_runtime0:46:13.945680
# 6)with parameters (2, 2, 1, 1), Performace: 0.89, mPos:6.50,SRate:0.50 time:0:00:10.584819, total_runtime0:46:24.530499
# 7)with parameters (2, 2, 1, 3), Performace: 0.14, mPos:0.00,SRate:0.00 time:0:00:10.530019, total_runtime0:46:35.060518
# 8)with parameters (2, 2, 1, 0), Performace: 0.92, mPos:6.50,SRate:0.38 time:0:00:10.592418, total_runtime0:46:45.652936
# 9)with parameters (2, 2, 3, 2), Performace: 0.38, mPos:0.83,SRate:0.00 time:0:00:10.608019, total_runtime0:46:56.276555
# 10)with parameters (2, 2, 3, 1), Performace: 0.68, mPos:4.83,SRate:0.17 time:0:00:10.623618, total_runtime0:47:06.900173
# 11)with parameters (2, 2, 3, 3), Performace: 0.14, mPos:0.00,SRate:0.00 time:0:00:10.639219, total_runtime0:47:17.539392
# 12)with parameters (2, 2, 3, 0), Performace: 0.73, mPos:5.33,SRate:0.17 time:0:00:11.298420, total_runtime0:47:28.837812
# 13)with parameters (2, 2, 0, 2), Performace: 0.59, mPos:2.50,SRate:0.50 time:0:00:10.483219, total_runtime0:47:39.321031
# 14)with parameters (2, 2, 0, 1), Performace: 0.97, mPos:6.50,SRate:0.50 time:0:00:10.530018, total_runtime0:47:49.851049
# 15)with parameters (2, 2, 0, 3), Performace: 0.14, mPos:0.00,SRate:0.00 time:0:00:10.530019, total_runtime0:48:00.381068
# 16)with parameters (2, 2, 0, 0), Performace: 0.89, mPos:6.50,SRate:0.00 time:0:00:10.576818, total_runtime0:48:10.957886
# 17)with parameters (2, 1, 2, 2), Performace: 0.67, mPos:5.50,SRate:0.40 time:0:00:10.561219, total_runtime0:48:21.519105
# 18)with parameters (2, 1, 2, 1), Performace: 0.33, mPos:30.00,SRate:0.33 time:0:00:10.592418, total_runtime0:48:32.111523
# 19)with parameters (2, 1, 2, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.514419, total_runtime0:48:42.625942
# 20)with parameters (2, 1, 2, 0), Performace: 0.40, mPos:37.00,SRate:0.28 time:0:00:10.592418, total_runtime0:48:53.218360
# 21)with parameters (2, 1, 1, 2), Performace: 0.55, mPos:16.50,SRate:0.42 time:0:00:10.594419, total_runtime0:49:03.812779
# 22)with parameters (2, 1, 1, 1), Performace: 0.49, mPos:51.17,SRate:0.24 time:0:00:10.576819, total_runtime0:49:14.389598
# 23)with parameters (2, 1, 1, 3), Performace: 0.39, mPos:0.17,SRate:0.00 time:0:00:10.670418, total_runtime0:49:25.060016
# 24)with parameters (2, 1, 1, 0), Performace: 0.70, mPos:54.17,SRate:0.24 time:0:00:10.670419, total_runtime0:49:35.730435
# 25)with parameters (2, 1, 3, 2), Performace: 0.24, mPos:1.83,SRate:0.00 time:0:00:10.547619, total_runtime0:49:46.278054
# 26)with parameters (2, 1, 3, 1), Performace: 0.73, mPos:15.83,SRate:0.32 time:0:00:10.483218, total_runtime0:49:56.761272
# 27)with parameters (2, 1, 3, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.610019, total_runtime0:50:07.371291
# 28)with parameters (2, 1, 3, 0), Performace: 0.38, mPos:23.67,SRate:0.26 time:0:00:10.562219, total_runtime0:50:17.933510
# 29)with parameters (2, 1, 0, 2), Performace: 0.31, mPos:4.67,SRate:0.12 time:0:00:10.545618, total_runtime0:50:28.479128
# 30)with parameters (2, 1, 0, 1), Performace: 0.45, mPos:65.17,SRate:0.35 time:0:00:10.577819, total_runtime0:50:39.056947
# 31)with parameters (2, 1, 0, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:10.562218, total_runtime0:50:49.619165
# 32)with parameters (2, 1, 0, 0), Performace: 0.89, mPos:69.83,SRate:0.01 time:0:00:10.639219, total_runtime0:51:00.258384
# 33)with parameters (2, 3, 2, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.608019, total_runtime0:51:10.866403
# 34)with parameters (2, 3, 2, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime0:51:21.646022
# 35)with parameters (2, 3, 2, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545618, total_runtime0:51:32.191640
# 36)with parameters (2, 3, 2, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545619, total_runtime0:51:42.737259
# 37)with parameters (2, 3, 1, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.639218, total_runtime0:51:53.376477
# 38)with parameters (2, 3, 1, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545619, total_runtime0:52:03.922096
# 39)with parameters (2, 3, 1, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.514418, total_runtime0:52:14.436514
# 40)with parameters (2, 3, 1, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.561219, total_runtime0:52:24.997733
# 41)with parameters (2, 3, 3, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.530018, total_runtime0:52:35.527751
# 42)with parameters (2, 3, 3, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545619, total_runtime0:52:46.073370
# 43)with parameters (2, 3, 3, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.530018, total_runtime0:52:56.603388
# 44)with parameters (2, 3, 3, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.592419, total_runtime0:53:07.195807
# 45)with parameters (2, 3, 0, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.623619, total_runtime0:53:17.819426
# 46)with parameters (2, 3, 0, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.654818, total_runtime0:53:28.474244
# 47)with parameters (2, 3, 0, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.592419, total_runtime0:53:39.066663
# 48)with parameters (2, 3, 0, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.530018, total_runtime0:53:49.596681
# 49)with parameters (2, 0, 2, 2), Performace: 0.62, mPos:5.50,SRate:0.36 time:0:00:10.561219, total_runtime0:54:00.157900
# 50)with parameters (2, 0, 2, 1), Performace: 0.36, mPos:36.50,SRate:0.28 time:0:00:10.561219, total_runtime0:54:10.719119
# 51)with parameters (2, 0, 2, 3), Performace: 0.08, mPos:0.00,SRate:0.00 time:0:00:10.592418, total_runtime0:54:21.311537
# 52)with parameters (2, 0, 2, 0), Performace: 0.43, mPos:46.00,SRate:0.24 time:0:00:10.576819, total_runtime0:54:31.888356
# 53)with parameters (2, 0, 1, 2), Performace: 0.46, mPos:17.33,SRate:0.46 time:0:00:10.530018, total_runtime0:54:42.418374
# 54)with parameters (2, 0, 1, 1), Performace: 0.62, mPos:78.00,SRate:0.29 time:0:00:10.608019, total_runtime0:54:53.026393
# 55)with parameters (2, 0, 1, 3), Performace: 0.18, mPos:0.17,SRate:0.00 time:0:00:10.530018, total_runtime0:55:03.556411
# 56)with parameters (2, 0, 1, 0), Performace: 0.53, mPos:88.33,SRate:0.25 time:0:00:10.576819, total_runtime0:55:14.148830
# 57)with parameters (2, 0, 3, 2), Performace: 0.60, mPos:1.67,SRate:0.00 time:0:00:10.748419, total_runtime0:55:24.897249
# 58)with parameters (2, 0, 3, 1), Performace: 0.54, mPos:16.83,SRate:0.38 time:0:00:10.592418, total_runtime0:55:35.489667
# 59)with parameters (2, 0, 3, 3), Performace: 0.08, mPos:0.00,SRate:0.00 time:0:00:10.498819, total_runtime0:55:45.988486
# 60)with parameters (2, 0, 3, 0), Performace: 0.29, mPos:27.17,SRate:0.32 time:0:00:10.545618, total_runtime0:55:56.534104
# 61)with parameters (2, 0, 0, 2), Performace: 0.85, mPos:4.67,SRate:0.12 time:0:00:10.624619, total_runtime0:56:07.158723
# 62)with parameters (2, 0, 0, 1), Performace: 1.18, mPos:112.50,SRate:0.34 time:0:00:10.561219, total_runtime0:56:17.719942
# 63)with parameters (2, 0, 0, 3), Performace: 0.08, mPos:0.00,SRate:0.00 time:0:00:10.498818, total_runtime0:56:28.218760
# 64)with parameters (2, 0, 0, 0), Performace: 0.87, mPos:203.00,SRate:0.11 time:0:00:10.842019, total_runtime0:56:39.060779
# 65)with parameters (1, 2, 2, 2), Performace: 0.60, mPos:5.00,SRate:0.33 time:0:00:10.533019, total_runtime0:56:49.593798
# 66)with parameters (1, 2, 2, 1), Performace: 0.62, mPos:11.67,SRate:0.22 time:0:00:10.498818, total_runtime0:57:00.092616
# 67)with parameters (1, 2, 2, 3), Performace: 0.12, mPos:0.00,SRate:0.00 time:0:00:10.561219, total_runtime0:57:10.653835
# 68)with parameters (1, 2, 2, 0), Performace: 0.61, mPos:13.17,SRate:0.11 time:0:00:10.717219, total_runtime0:57:21.371054
# 69)with parameters (1, 2, 1, 2), Performace: 0.46, mPos:8.00,SRate:0.29 time:0:00:11.122819, total_runtime0:57:32.493873
# 70)with parameters (1, 2, 1, 1), Performace: 0.76, mPos:14.00,SRate:0.37 time:0:00:11.154020, total_runtime0:57:43.647893
# 71)with parameters (1, 2, 1, 3), Performace: 0.11, mPos:0.17,SRate:0.00 time:0:00:11.139419, total_runtime0:57:54.787312
# 72)with parameters (1, 2, 1, 0), Performace: 0.91, mPos:14.17,SRate:0.42 time:0:00:10.802220, total_runtime0:58:05.589532
# 73)with parameters (1, 2, 3, 2), Performace: 0.16, mPos:1.67,SRate:0.00 time:0:00:10.857619, total_runtime0:58:16.447151
# 74)with parameters (1, 2, 3, 1), Performace: 0.51, mPos:10.33,SRate:0.31 time:0:00:10.592418, total_runtime0:58:27.039569
# 75)with parameters (1, 2, 3, 3), Performace: 0.12, mPos:0.00,SRate:0.00 time:0:00:10.514419, total_runtime0:58:37.553988
# 76)with parameters (1, 2, 3, 0), Performace: 0.51, mPos:11.33,SRate:0.27 time:0:00:10.578219, total_runtime0:58:48.132207
# 77)with parameters (1, 2, 0, 2), Performace: 0.43, mPos:3.83,SRate:0.25 time:0:00:10.514419, total_runtime0:58:58.646626
# 78)with parameters (1, 2, 0, 1), Performace: 0.75, mPos:14.33,SRate:0.42 time:0:00:10.530018, total_runtime0:59:09.176644
# 79)with parameters (1, 2, 0, 3), Performace: 0.12, mPos:0.00,SRate:0.00 time:0:00:10.623619, total_runtime0:59:19.800263
# 80)with parameters (1, 2, 0, 0), Performace: 0.86, mPos:14.67,SRate:0.00 time:0:00:10.561219, total_runtime0:59:30.361482
# 81)with parameters (1, 1, 2, 2), Performace: 0.82, mPos:5.83,SRate:0.42 time:0:00:10.561218, total_runtime0:59:40.922700
# 82)with parameters (1, 1, 2, 1), Performace: 0.77, mPos:51.67,SRate:0.25 time:0:00:10.592419, total_runtime0:59:51.530719
# 83)with parameters (1, 1, 2, 3), Performace: 0.49, mPos:0.00,SRate:0.00 time:0:00:10.498818, total_runtime1:00:02.029537
# 84)with parameters (1, 1, 2, 0), Performace: 0.28, mPos:75.67,SRate:0.22 time:0:00:10.545619, total_runtime1:00:12.575156
# 85)with parameters (1, 1, 1, 2), Performace: 0.38, mPos:17.33,SRate:0.38 time:0:00:10.701619, total_runtime1:00:23.276775
# 86)with parameters (1, 1, 1, 1), Performace: 0.36, mPos:104.17,SRate:0.33 time:0:00:10.592418, total_runtime1:00:33.869193
# 87)with parameters (1, 1, 1, 3), Performace: 0.41, mPos:0.17,SRate:0.00 time:0:00:10.532019, total_runtime1:00:44.401212
# 88)with parameters (1, 1, 1, 0), Performace: 0.25, mPos:128.50,SRate:0.30 time:0:00:10.699019, total_runtime1:00:55.100231
# 89)with parameters (1, 1, 3, 2), Performace: 0.48, mPos:1.83,SRate:0.00 time:0:00:10.515419, total_runtime1:01:05.615650
# 90)with parameters (1, 1, 3, 1), Performace: 0.45, mPos:21.00,SRate:0.33 time:0:00:10.545618, total_runtime1:01:16.161268
# 91)with parameters (1, 1, 3, 3), Performace: 0.49, mPos:0.00,SRate:0.00 time:0:00:10.779619, total_runtime1:01:26.940887
# 92)with parameters (1, 1, 3, 0), Performace: 0.07, mPos:36.67,SRate:0.22 time:0:00:10.545619, total_runtime1:01:37.486506
# 93)with parameters (1, 1, 0, 2), Performace: 0.45, mPos:4.83,SRate:0.11 time:0:00:10.545618, total_runtime1:01:48.032124
# 94)with parameters (1, 1, 0, 1), Performace: 0.34, mPos:141.33,SRate:0.35 time:0:00:10.686019, total_runtime1:01:58.718143
# 95)with parameters (1, 1, 0, 3), Performace: 0.49, mPos:0.00,SRate:0.00 time:0:00:10.514419, total_runtime1:02:09.232562
# 96)with parameters (1, 1, 0, 0), Performace: 0.85, mPos:183.33,SRate:0.10 time:0:00:10.686018, total_runtime1:02:19.918580
# 97)with parameters (1, 3, 2, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.561219, total_runtime1:02:30.479799
# 98)with parameters (1, 3, 2, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.514418, total_runtime1:02:40.994217
# 99)with parameters (1, 3, 2, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.498819, total_runtime1:02:51.493036
# 100)with parameters (1, 3, 2, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545618, total_runtime1:03:02.038654
# 101)with parameters (1, 3, 1, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.576819, total_runtime1:03:12.615473
# 102)with parameters (1, 3, 1, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.702619, total_runtime1:03:23.333692
# 103)with parameters (1, 3, 1, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545618, total_runtime1:03:33.879310
# 104)with parameters (1, 3, 1, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.576819, total_runtime1:03:44.456129
# 105)with parameters (1, 3, 3, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545618, total_runtime1:03:55.001747
# 106)with parameters (1, 3, 3, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.561219, total_runtime1:04:05.562966
# 107)with parameters (1, 3, 3, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.561218, total_runtime1:04:16.124184
# 108)with parameters (1, 3, 3, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545619, total_runtime1:04:26.669803
# 109)with parameters (1, 3, 0, 2), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.576819, total_runtime1:04:37.246622
# 110)with parameters (1, 3, 0, 1), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.483218, total_runtime1:04:47.729840
# 111)with parameters (1, 3, 0, 3), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.576819, total_runtime1:04:58.306659
# 112)with parameters (1, 3, 0, 0), Performace: 0.89, mPos:0.00,SRate:0.00 time:0:00:10.545618, total_runtime1:05:08.852277
# 113)with parameters (1, 0, 2, 2), Performace: 0.22, mPos:5.67,SRate:0.36 time:0:00:10.639219, total_runtime1:05:19.491496
# 114)with parameters (1, 0, 2, 1), Performace: 0.28, mPos:50.17,SRate:0.26 time:0:00:10.609018, total_runtime1:05:30.100514
# 115)with parameters (1, 0, 2, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.578819, total_runtime1:05:40.679333
# 116)with parameters (1, 0, 2, 0), Performace: 0.37, mPos:82.17,SRate:0.22 time:0:00:10.545619, total_runtime1:05:51.224952
# 117)with parameters (1, 0, 1, 2), Performace: 0.32, mPos:17.67,SRate:0.38 time:0:00:10.592418, total_runtime1:06:01.817370
# 118)with parameters (1, 0, 1, 1), Performace: 0.31, mPos:126.50,SRate:0.30 time:0:00:10.639219, total_runtime1:06:12.456589
# 119)with parameters (1, 0, 1, 3), Performace: 0.25, mPos:0.17,SRate:0.00 time:0:00:10.545618, total_runtime1:06:23.002207
# 120)with parameters (1, 0, 1, 0), Performace: 0.76, mPos:166.00,SRate:0.35 time:0:00:10.717219, total_runtime1:06:33.719426
# 121)with parameters (1, 0, 3, 2), Performace: 0.35, mPos:1.83,SRate:0.00 time:0:00:10.576819, total_runtime1:06:44.296245
# 122)with parameters (1, 0, 3, 1), Performace: 0.39, mPos:20.33,SRate:0.38 time:0:00:10.530018, total_runtime1:06:54.826263
# 123)with parameters (1, 0, 3, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.545619, total_runtime1:07:05.371882
# 124)with parameters (1, 0, 3, 0), Performace: 0.24, mPos:39.33,SRate:0.24 time:0:00:10.654819, total_runtime1:07:16.026701
# 125)with parameters (1, 0, 0, 2), Performace: 0.76, mPos:5.00,SRate:0.22 time:0:00:10.826419, total_runtime1:07:26.853120
# 126)with parameters (1, 0, 0, 1), Performace: 0.94, mPos:182.33,SRate:0.33 time:0:00:10.717218, total_runtime1:07:37.570338
# 127)with parameters (1, 0, 0, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.608019, total_runtime1:07:48.178357
# 129)with parameters (3, 2, 2, 2), Performace: 0.69, mPos:1.50,SRate:0.00 time:0:00:10.654819, total_runtime1:07:58.833176
# 130)with parameters (3, 2, 2, 1), Performace: 0.90, mPos:2.17,SRate:0.50 time:0:00:10.608018, total_runtime1:08:09.441194
# 131)with parameters (3, 2, 2, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.608019, total_runtime1:08:20.049213
# 132)with parameters (3, 2, 2, 0), Performace: 0.92, mPos:2.17,SRate:0.50 time:0:00:10.654819, total_runtime1:08:30.704032
# 133)with parameters (3, 2, 1, 2), Performace: 0.69, mPos:2.33,SRate:0.33 time:0:00:10.654818, total_runtime1:08:41.358850
# 134)with parameters (3, 2, 1, 1), Performace: 0.82, mPos:2.33,SRate:0.67 time:0:00:10.623619, total_runtime1:08:51.982469
# 135)with parameters (3, 2, 1, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.592419, total_runtime1:09:02.574888
# 136)with parameters (3, 2, 1, 0), Performace: 0.81, mPos:2.33,SRate:0.33 time:0:00:10.623618, total_runtime1:09:13.198506
# 137)with parameters (3, 2, 3, 2), Performace: 0.66, mPos:0.83,SRate:0.00 time:0:00:10.732819, total_runtime1:09:23.931325
# 138)with parameters (3, 2, 3, 1), Performace: 0.76, mPos:2.17,SRate:0.00 time:0:00:10.639219, total_runtime1:09:34.570544
# 139)with parameters (3, 2, 3, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.608019, total_runtime1:09:45.178563
# 140)with parameters (3, 2, 3, 0), Performace: 0.83, mPos:2.17,SRate:0.00 time:0:00:10.467618, total_runtime1:09:55.646181
# 141)with parameters (3, 2, 0, 2), Performace: 0.83, mPos:1.83,SRate:0.00 time:0:00:10.576819, total_runtime1:10:06.223000
# 142)with parameters (3, 2, 0, 1), Performace: 0.86, mPos:2.33,SRate:0.33 time:0:00:10.561218, total_runtime1:10:16.784218
# 143)with parameters (3, 2, 0, 3), Performace: 0.34, mPos:0.00,SRate:0.00 time:0:00:10.545619, total_runtime1:10:27.329837
# 144)with parameters (3, 2, 0, 0), Performace: 0.89, mPos:2.33,SRate:0.00 time:0:00:10.548618, total_runtime1:10:37.878455
# ...
# 122)with parameters (1, 0, 3, 1), Performace: 0.22, mPos:14.33,SRate:0.31 time:0:00:09.594017, total_runtime6:40:50.859083
# 123)with parameters (1, 0, 3, 3), Performace: 0.19, mPos:0.00,SRate:0.00 time:0:00:09.640817, total_runtime6:41:00.499900
# 124)with parameters (1, 0, 3, 0), Performace: 0.31, mPos:25.83,SRate:0.45 time:0:00:09.594017, total_runtime6:41:10.093917
# 125)with parameters (1, 0, 0, 2), Performace: 0.50, mPos:5.33,SRate:0.67 time:0:00:09.547217, total_runtime6:41:19.641134
# 126)with parameters (1, 0, 0, 1), Performace: 0.73, mPos:147.00,SRate:0.39 time:0:00:09.843617, total_runtime6:41:29.484751
# 127)with parameters (1, 0, 0, 3), Performace: 0.19, mPos:0.00,SRate:0.00 time:0:00:09.516017, total_runtime6:41:39.000768
# 129)with parameters (3, 2, 2, 2), Performace: 0.43, mPos:1.33,SRate:0.00 time:0:00:09.578417, total_runtime6:41:48.579185
# 130)with parameters (3, 2, 2, 1), Performace: 0.72, mPos:2.00,SRate:0.50 time:0:00:09.531616, total_runtime6:41:58.126401
# 131)with parameters (3, 2, 2, 3), Performace: 0.47, mPos:0.00,SRate:0.00 time:0:00:09.594017, total_runtime6:42:07.720418
# 132)with parameters (3, 2, 2, 0), Performace: 0.69, mPos:2.17,SRate:0.00 time:0:00:09.562817, total_runtime6:42:17.283235
# 133)with parameters (3, 2, 1, 2), Performace: 0.53, mPos:2.17,SRate:0.00 time:0:00:09.656417, total_runtime6:42:26.939652
# 134)with parameters (3, 2, 1, 1), Performace: 0.65, mPos:2.17,SRate:0.50 time:0:00:09.531617, total_runtime6:42:36.471269
# 135)with parameters (3, 2, 1, 3), Performace: 0.59, mPos:0.17,SRate:1.00 time:0:00:09.656417, total_runtime6:42:46.127686
# 136)with parameters (3, 2, 1, 0), Performace: 0.66, mPos:2.17,SRate:0.00 time:0:00:09.531616, total_runtime6:42:55.659302
# 137)with parameters (3, 2, 3, 2), Performace: 0.28, mPos:0.33,SRate:0.00 time:0:00:09.547217, total_runtime6:43:05.206519
# 138)with parameters (3, 2, 3, 1), Performace: 0.74, mPos:1.83,SRate:0.50 time:0:00:09.547217, total_runtime6:43:14.753736
# 139)with parameters (3, 2, 3, 3), Performace: 0.47, mPos:0.00,SRate:0.00 time:0:00:09.703217, total_runtime6:43:24.456953
# 140)with parameters (3, 2, 3, 0), Performace: 0.67, mPos:1.83,SRate:0.00 time:0:00:09.594017, total_runtime6:43:34.050970
# 141)with parameters (3, 2, 0, 2), Performace: 0.50, mPos:1.50,SRate:0.50 time:0:00:09.516017, total_runtime6:43:43.566987
# 142)with parameters (3, 2, 0, 1), Performace: 0.70, mPos:2.17,SRate:0.50 time:0:00:09.578416, total_runtime6:43:53.145403
# 143)with parameters (3, 2, 0, 3), Performace: 0.47, mPos:0.00,SRate:0.00 time:0:00:09.656417, total_runtime6:44:02.801820
# 144)with parameters (3, 2, 0, 0), Performace: 0.71, mPos:2.33,SRate:0.00 time:0:00:09.594017, total_runtime6:44:12.395837
# 145)with parameters (3, 1, 2, 2), Performace: 0.34, mPos:3.50,SRate:0.60 time:0:00:09.578417, total_runtime6:44:21.974254
# 146)with parameters (3, 1, 2, 1), Performace: 0.61, mPos:12.67,SRate:0.47 time:0:00:09.578417, total_runtime6:44:31.552671
# 147)with parameters (3, 1, 2, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:09.843617, total_runtime6:44:41.396288
# 148)with parameters (3, 1, 2, 0), Performace: 0.73, mPos:16.00,SRate:0.39 time:0:00:09.578417, total_runtime6:44:50.974705
# 149)with parameters (3, 1, 1, 2), Performace: 0.60, mPos:8.67,SRate:0.80 time:0:00:09.611617, total_runtime6:45:00.586322
# 150)with parameters (3, 1, 1, 1), Performace: 0.69, mPos:21.33,SRate:0.43 time:0:00:09.500417, total_runtime6:45:10.086739
# 151)with parameters (3, 1, 1, 3), Performace: 0.40, mPos:0.33,SRate:1.00 time:0:00:09.859217, total_runtime6:45:19.945956
# 152)with parameters (3, 1, 1, 0), Performace: 0.65, mPos:21.00,SRate:0.42 time:0:00:09.703217, total_runtime6:45:29.649173
# 153)with parameters (3, 1, 3, 2), Performace: 0.14, mPos:1.33,SRate:0.00 time:0:00:09.516017, total_runtime6:45:39.165190
# 154)with parameters (3, 1, 3, 1), Performace: 0.49, mPos:7.17,SRate:0.43 time:0:00:09.578417, total_runtime6:45:48.743607
# 155)with parameters (3, 1, 3, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:09.656416, total_runtime6:45:58.400023
# 156)with parameters (3, 1, 3, 0), Performace: 0.52, mPos:10.67,SRate:0.53 time:0:00:09.562817, total_runtime6:46:07.962840
# 157)with parameters (3, 1, 0, 2), Performace: 0.39, mPos:4.00,SRate:1.00 time:0:00:09.578417, total_runtime6:46:17.541257
# 158)with parameters (3, 1, 0, 1), Performace: 0.73, mPos:25.33,SRate:0.44 time:0:00:09.594017, total_runtime6:46:27.135274
# 159)with parameters (3, 1, 0, 3), Performace: 0.25, mPos:0.00,SRate:0.00 time:0:00:09.781217, total_runtime6:46:36.916491
# 160)with parameters (3, 1, 0, 0), Performace: 0.71, mPos:27.17,SRate:0.03 time:0:00:09.562817, total_runtime6:46:46.479308
# 161)with parameters (3, 3, 2, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.516017, total_runtime6:46:55.995325
# 162)with parameters (3, 3, 2, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.531616, total_runtime6:47:05.526941
# 163)with parameters (3, 3, 2, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.952818, total_runtime6:47:15.479759
# 164)with parameters (3, 3, 2, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.625217, total_runtime6:47:25.104976
# 165)with parameters (3, 3, 1, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.531616, total_runtime6:47:34.636592
# 166)with parameters (3, 3, 1, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562816, total_runtime6:47:44.215009
# 167)with parameters (3, 3, 1, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.547217, total_runtime6:47:53.762226
# 168)with parameters (3, 3, 1, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.516017, total_runtime6:48:03.278243
# 169)with parameters (3, 3, 3, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:48:12.841060
# 170)with parameters (3, 3, 3, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.531616, total_runtime6:48:22.372676
# 171)with parameters (3, 3, 3, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.578417, total_runtime6:48:31.951093
# 172)with parameters (3, 3, 3, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:48:41.513910
# 173)with parameters (3, 3, 0, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.547217, total_runtime6:48:51.061127
# 174)with parameters (3, 3, 0, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.751017, total_runtime6:49:00.812144
# 175)with parameters (3, 3, 0, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.859217, total_runtime6:49:10.671361
# 176)with parameters (3, 3, 0, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.516017, total_runtime6:49:20.187378
# 177)with parameters (3, 0, 2, 2), Performace: 0.37, mPos:3.67,SRate:0.60 time:0:00:09.703217, total_runtime6:49:29.890595
# 178)with parameters (3, 0, 2, 1), Performace: 0.94, mPos:17.00,SRate:0.36 time:0:00:09.594017, total_runtime6:49:39.484612
# 179)with parameters (3, 0, 2, 3), Performace: 0.31, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:49:49.047429
# 180)with parameters (3, 0, 2, 0), Performace: 0.89, mPos:20.50,SRate:0.31 time:0:00:09.578416, total_runtime6:49:58.625845
# 181)with parameters (3, 0, 1, 2), Performace: 0.64, mPos:10.50,SRate:0.83 time:0:00:09.625217, total_runtime6:50:08.251062
# 182)with parameters (3, 0, 1, 1), Performace: 0.82, mPos:32.50,SRate:0.40 time:0:00:09.594017, total_runtime6:50:17.845079
# 183)with parameters (3, 0, 1, 3), Performace: 0.34, mPos:0.33,SRate:1.00 time:0:00:09.625217, total_runtime6:50:27.470296
# 184)with parameters (3, 0, 1, 0), Performace: 0.58, mPos:34.67,SRate:0.38 time:0:00:09.609617, total_runtime6:50:37.079913
# 185)with parameters (3, 0, 3, 2), Performace: 0.07, mPos:1.33,SRate:0.00 time:0:00:09.562817, total_runtime6:50:46.642730
# 186)with parameters (3, 0, 3, 1), Performace: 0.49, mPos:8.83,SRate:0.44 time:0:00:09.531617, total_runtime6:50:56.174347
# 187)with parameters (3, 0, 3, 3), Performace: 0.31, mPos:0.00,SRate:0.00 time:0:00:09.703217, total_runtime6:51:05.877564
# 188)with parameters (3, 0, 3, 0), Performace: 0.49, mPos:12.33,SRate:0.56 time:0:00:09.547216, total_runtime6:51:15.424780
# 189)with parameters (3, 0, 0, 2), Performace: 0.42, mPos:4.67,SRate:0.75 time:0:00:09.595017, total_runtime6:51:25.019797
# 190)with parameters (3, 0, 0, 1), Performace: 0.61, mPos:41.83,SRate:0.50 time:0:00:09.656417, total_runtime6:51:34.676214
# 191)with parameters (3, 0, 0, 3), Performace: 0.31, mPos:0.00,SRate:0.00 time:0:00:09.578417, total_runtime6:51:44.254631
# 192)with parameters (3, 0, 0, 0), Performace: 0.72, mPos:73.00,SRate:0.10 time:0:00:09.625217, total_runtime6:51:53.879848
# 193)with parameters (0, 2, 2, 2), Performace: 0.53, mPos:2.00,SRate:0.33 time:0:00:09.673017, total_runtime6:52:03.552865
# 194)with parameters (0, 2, 2, 1), Performace: 0.82, mPos:4.00,SRate:0.50 time:0:00:09.594017, total_runtime6:52:13.146882
# 195)with parameters (0, 2, 2, 3), Performace: 0.00, mPos:0.00,SRate:0.00 time:0:00:09.687617, total_runtime6:52:22.834499
# 196)with parameters (0, 2, 2, 0), Performace: 0.67, mPos:4.00,SRate:0.38 time:0:00:09.609617, total_runtime6:52:32.444116
# 197)with parameters (0, 2, 1, 2), Performace: 0.58, mPos:3.00,SRate:0.40 time:0:00:09.516016, total_runtime6:52:41.960132
# 198)with parameters (0, 2, 1, 1), Performace: 0.75, mPos:4.00,SRate:0.38 time:0:00:09.469217, total_runtime6:52:51.444949
# 199)with parameters (0, 2, 1, 3), Performace: 0.00, mPos:0.33,SRate:1.00 time:0:00:09.578417, total_runtime6:53:01.023366
# 200)with parameters (0, 2, 1, 0), Performace: 0.72, mPos:4.00,SRate:0.38 time:0:00:09.516017, total_runtime6:53:10.539383
# 201)with parameters (0, 2, 3, 2), Performace: 0.25, mPos:1.00,SRate:0.00 time:0:00:09.484816, total_runtime6:53:20.024199
# 202)with parameters (0, 2, 3, 1), Performace: 0.64, mPos:3.33,SRate:0.60 time:0:00:09.640817, total_runtime6:53:29.665016
# 203)with parameters (0, 2, 3, 3), Performace: 0.00, mPos:0.00,SRate:0.00 time:0:00:09.547217, total_runtime6:53:39.212233
# 204)with parameters (0, 2, 3, 0), Performace: 0.51, mPos:3.67,SRate:0.43 time:0:00:09.547217, total_runtime6:53:48.759450
# 205)with parameters (0, 2, 0, 2), Performace: 0.39, mPos:2.50,SRate:1.00 time:0:00:09.578417, total_runtime6:53:58.337867
# 206)with parameters (0, 2, 0, 1), Performace: 0.71, mPos:4.00,SRate:0.38 time:0:00:09.531616, total_runtime6:54:07.869483
# 207)with parameters (0, 2, 0, 3), Performace: 0.00, mPos:0.00,SRate:0.00 time:0:00:09.609617, total_runtime6:54:17.479100
# 208)with parameters (0, 2, 0, 0), Performace: 0.71, mPos:4.00,SRate:0.12 time:0:00:09.578417, total_runtime6:54:27.057517
# 209)with parameters (0, 1, 2, 2), Performace: 0.39, mPos:4.83,SRate:0.57 time:0:00:09.562817, total_runtime6:54:36.620334
# 210)with parameters (0, 1, 2, 1), Performace: 0.42, mPos:46.83,SRate:0.38 time:0:00:09.578417, total_runtime6:54:46.198751
# 211)with parameters (0, 1, 2, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:09.625217, total_runtime6:54:55.823968
# 212)with parameters (0, 1, 2, 0), Performace: 0.75, mPos:82.33,SRate:0.28 time:0:00:09.609616, total_runtime6:55:05.433584
# 213)with parameters (0, 1, 1, 2), Performace: 0.58, mPos:13.00,SRate:0.71 time:0:00:09.625217, total_runtime6:55:15.058801
# 214)with parameters (0, 1, 1, 1), Performace: 0.79, mPos:111.17,SRate:0.40 time:0:00:09.828018, total_runtime6:55:24.886819
# 215)with parameters (0, 1, 1, 3), Performace: 0.44, mPos:0.33,SRate:1.00 time:0:00:09.609616, total_runtime6:55:34.496435
# 216)with parameters (0, 1, 1, 0), Performace: 0.25, mPos:144.00,SRate:0.36 time:0:00:09.734418, total_runtime6:55:44.230853
# 217)with parameters (0, 1, 3, 2), Performace: 0.15, mPos:1.33,SRate:0.00 time:0:00:09.547216, total_runtime6:55:53.778069
# 218)with parameters (0, 1, 3, 1), Performace: 0.22, mPos:16.67,SRate:0.47 time:0:00:09.594017, total_runtime6:56:03.372086
# 219)with parameters (0, 1, 3, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:56:12.934903
# 220)with parameters (0, 1, 3, 0), Performace: 0.56, mPos:31.50,SRate:0.50 time:0:00:09.609617, total_runtime6:56:22.544520
# 221)with parameters (0, 1, 0, 2), Performace: 0.44, mPos:5.33,SRate:0.78 time:0:00:09.547217, total_runtime6:56:32.091737
# 222)with parameters (0, 1, 0, 1), Performace: 0.81, mPos:130.33,SRate:0.65 time:0:00:09.640817, total_runtime6:56:41.732554
# 223)with parameters (0, 1, 0, 3), Performace: 0.38, mPos:0.00,SRate:0.00 time:0:00:09.625216, total_runtime6:56:51.357770
# 225)with parameters (0, 3, 2, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.500417, total_runtime6:57:00.858187
# 226)with parameters (0, 3, 2, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:57:10.421004
# 227)with parameters (0, 3, 2, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.547217, total_runtime6:57:19.968221
# 228)with parameters (0, 3, 2, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.734417, total_runtime6:57:29.702638
# 229)with parameters (0, 3, 1, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.565817, total_runtime6:57:39.268455
# 230)with parameters (0, 3, 1, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:57:48.831272
# 231)with parameters (0, 3, 1, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.516016, total_runtime6:57:58.347288
# 232)with parameters (0, 3, 1, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.656417, total_runtime6:58:08.003705
# 233)with parameters (0, 3, 3, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.531617, total_runtime6:58:17.535322
# 234)with parameters (0, 3, 3, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.564817, total_runtime6:58:27.100139
# 235)with parameters (0, 3, 3, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.615617, total_runtime6:58:36.715756
# 236)with parameters (0, 3, 3, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:58:46.278573
# 237)with parameters (0, 3, 0, 2), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.531617, total_runtime6:58:55.810190
# 238)with parameters (0, 3, 0, 1), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.562816, total_runtime6:59:05.373006
# 239)with parameters (0, 3, 0, 3), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.516017, total_runtime6:59:14.889023
# 240)with parameters (0, 3, 0, 0), Performace: 0.71, mPos:0.00,SRate:0.00 time:0:00:09.718817, total_runtime6:59:24.607840
# 241)with parameters (0, 0, 2, 2), Performace: 0.34, mPos:4.83,SRate:0.43 time:0:00:09.609617, total_runtime6:59:34.217457
# 242)with parameters (0, 0, 2, 1), Performace: 0.58, mPos:51.67,SRate:0.35 time:0:00:09.562817, total_runtime6:59:43.780274
# 243)with parameters (0, 0, 2, 3), Performace: 0.31, mPos:0.00,SRate:0.00 time:0:00:09.562817, total_runtime6:59:53.343091
# 244)with parameters (0, 0, 2, 0), Performace: 0.39, mPos:127.17,SRate:0.25 time:0:00:09.703217, total_runtime7:00:03.046308
# 245)with parameters (0, 0, 1, 2), Performace: 0.25, mPos:13.17,SRate:0.64 time:0:00:09.562817, total_runtime7:00:12.609125
# 246)with parameters (0, 0, 1, 1), Performace: 0.58, mPos:140.67,SRate:0.42 time:0:00:09.656417, total_runtime7:00:22.265542
# 247)with parameters (0, 0, 1, 3), Performace: 0.25, mPos:0.33,SRate:1.00 time:0:00:09.578416, total_runtime7:00:31.843958
# 249)with parameters (0, 0, 3, 2), Performace: 0.20, mPos:1.33,SRate:0.00 time:0:00:09.578417, total_runtime7:00:41.422375
# 250)with parameters (0, 0, 3, 1), Performace: 0.46, mPos:17.50,SRate:0.33 time:0:00:09.625217, total_runtime7:00:51.047592
# 251)with parameters (0, 0, 3, 3), Performace: 0.31, mPos:0.00,SRate:0.00 time:0:00:09.531617, total_runtime7:01:00.579209
# 252)with parameters (0, 0, 3, 0), Performace: 0.42, mPos:50.00,SRate:0.28 time:0:00:09.547217, total_runtime7:01:10.126426
# 253)with parameters (0, 0, 0, 2), Performace: 0.47, mPos:5.33,SRate:0.67 time:0:00:09.500416, total_runtime7:01:19.642442
# 255)with parameters (0, 0, 0, 3), Performace: 0.31, mPos:0.00,SRate:0.00 time:0:00:09.703217, total_runtime7:01:29.345659

# %%
# performance_check=pd.read_csv("PerformanceCheck.csv")
candidates=performance_check.groupby("params",as_index=False)["params","results","Positions","final_values"].mean().sort_values(by="results",ascending=False)
parameters1=[[int(j) for j in i[1:-1].split(",")] for i in candidates[candidates["Positions"]>=75]["params"].tolist()]
parameters=[]
for i in parameters1:
    if i[2]==0 and i[3]==0:
        continue
    else:
        parameters.append(i)
    if len(parameters)==5:
        break
parameters
# Out:
# [[3, 1, 0, 1], [1, 2, 0, 1], [1, 2, 1, 0], [3, 1, 1, 0], [3, 1, 1, 1]]

# %% [markdown]
# ## Applying the model
# After extracting 5 candidates from our limited model, we can add the sentiment signals that we assembled, and try all different combination in order to see which one will give us the best results.

# %%
stock_list=DATA["ticker"].unique().tolist()
sentiments=[None,"Q_aggscore1","Q_aggscore2","Q_aggscore1_SD","Q_aggscore1_SD4","Q_aggscore2_SD","Q_aggscore2_SD4"]
cash=100000
params_performance=[]
time1=datetime.now()
ToConcat=[]
DATA.sort_values(["ticker","date"])
iterations=0
for sentiment in sentiments:
    params=parameters
    stocks=random.sample(stock_list,len(stock_list))
    for loop,param in enumerate(params,1):
        tradePerformance=[]
        stockPerformance=[]
        lenPosition=[]
        successfullPositions=[]
        cash=100000
        time2=datetime.now()
        print("Sentiment index is: {}, Parameters are: {}, Elapsed time: {}, Elapsed iterations: {}".
              format(sentiment,param,datetime.now()-time1,iterations))
        for idxs,CurrentStock in enumerate(stocks):
            iterations+=1
            account={"Holding":0,"Cash":cash}
            stock=DATA[DATA["ticker"]==CurrentStock].dropna(subset=["Positives"]).sort_values("date").reset_index(drop=True)
            tP,sP,lP,rP=tradeSentiment(param,stock,account,sentiment)
            tradePerformance.append(tP)
            stockPerformance.append(sP)
            lenPosition.append(lP)
            successfullPositions.append(rP)
            if idxs%500==0:
                pass
#                 print("{}) Elapsed time: {}, Elapsed iterations: {}".format(idxs,datetime.now()-time1,iterations))
        params_performance.append([sentiment,param,sum(tradePerformance)/sum(stockPerformance),sum(lenPosition),sum(successfullPositions),datetime.now()-time2])
#         if loop==3:
#             break
#     break
print("Total Time: {}, # of iterations: {}".format(datetime.now()-time1,iterations))
results=pd.DataFrame(params_performance,columns=["sentiment","params","performance","positions","successfull","time"])
results.to_csv("final_results.csv",index_label=False)
results["ratio"]=results.successfull/results.positions
# Out:
# Sentiment index is: None, Parameters are: [3, 1, 0, 1], Elapsed time: 0:00:04.851609, Elapsed iterations: 0
# Sentiment index is: None, Parameters are: [1, 2, 0, 1], Elapsed time: 1:17:38.800791, Elapsed iterations: 2708
# Sentiment index is: None, Parameters are: [1, 2, 1, 0], Elapsed time: 2:35:07.592365, Elapsed iterations: 5416
# Sentiment index is: None, Parameters are: [3, 1, 1, 0], Elapsed time: 3:52:37.527142, Elapsed iterations: 8124
# Sentiment index is: None, Parameters are: [3, 1, 1, 1], Elapsed time: 5:10:14.336125, Elapsed iterations: 10832
# Sentiment index is: Q_aggscore1, Parameters are: [3, 1, 0, 1], Elapsed time: 6:27:49.780708, Elapsed iterations: 13540
# Sentiment index is: Q_aggscore1, Parameters are: [1, 2, 0, 1], Elapsed time: 7:48:48.731846, Elapsed iterations: 16248
# Sentiment index is: Q_aggscore1, Parameters are: [1, 2, 1, 0], Elapsed time: 9:09:47.052987, Elapsed iterations: 18956
# Sentiment index is: Q_aggscore1, Parameters are: [3, 1, 1, 0], Elapsed time: 10:31:04.150962, Elapsed iterations: 21664
# Sentiment index is: Q_aggscore1, Parameters are: [3, 1, 1, 1], Elapsed time: 11:52:08.754112, Elapsed iterations: 24372
# Sentiment index is: Q_aggscore2, Parameters are: [3, 1, 0, 1], Elapsed time: 13:14:13.510354, Elapsed iterations: 27080
# Sentiment index is: Q_aggscore2, Parameters are: [1, 2, 0, 1], Elapsed time: 14:35:42.981150, Elapsed iterations: 29788
# Sentiment index is: Q_aggscore2, Parameters are: [1, 2, 1, 0], Elapsed time: 15:56:45.695296, Elapsed iterations: 32496
# Sentiment index is: Q_aggscore2, Parameters are: [3, 1, 1, 0], Elapsed time: 17:17:52.287853, Elapsed iterations: 35204
# Sentiment index is: Q_aggscore2, Parameters are: [3, 1, 1, 1], Elapsed time: 19:39:01.002212, Elapsed iterations: 37912
# Sentiment index is: Q_aggscore1_SD, Parameters are: [3, 1, 0, 1], Elapsed time: 21:00:09.666568, Elapsed iterations: 40620
# Sentiment index is: Q_aggscore1_SD, Parameters are: [1, 2, 0, 1], Elapsed time: 22:21:23.811336, Elapsed iterations: 43328
# Sentiment index is: Q_aggscore1_SD, Parameters are: [1, 2, 1, 0], Elapsed time: 23:42:30.501493, Elapsed iterations: 46036
# Sentiment index is: Q_aggscore1_SD, Parameters are: [3, 1, 1, 0], Elapsed time: 1 day, 1:03:40.401251, Elapsed iterations: 48744
# Sentiment index is: Q_aggscore1_SD, Parameters are: [3, 1, 1, 1], Elapsed time: 1 day, 2:24:52.024017, Elapsed iterations: 51452
# Sentiment index is: Q_aggscore1_SD4, Parameters are: [3, 1, 0, 1], Elapsed time: 1 day, 3:46:01.349178, Elapsed iterations: 54160
# Sentiment index is: Q_aggscore1_SD4, Parameters are: [1, 2, 0, 1], Elapsed time: 1 day, 5:07:14.313745, Elapsed iterations: 56868
# Sentiment index is: Q_aggscore1_SD4, Parameters are: [1, 2, 1, 0], Elapsed time: 1 day, 6:28:40.329737, Elapsed iterations: 59576
# Sentiment index is: Q_aggscore1_SD4, Parameters are: [3, 1, 1, 0], Elapsed time: 1 day, 7:49:57.979911, Elapsed iterations: 62284
# Sentiment index is: Q_aggscore1_SD4, Parameters are: [3, 1, 1, 1], Elapsed time: 1 day, 9:11:15.033685, Elapsed iterations: 64992
# Sentiment index is: Q_aggscore2_SD, Parameters are: [3, 1, 0, 1], Elapsed time: 1 day, 10:32:35.688069, Elapsed iterations: 67700
# Sentiment index is: Q_aggscore2_SD, Parameters are: [1, 2, 0, 1], Elapsed time: 1 day, 11:53:57.763048, Elapsed iterations: 70408
# Sentiment index is: Q_aggscore2_SD, Parameters are: [1, 2, 1, 0], Elapsed time: 1 day, 13:15:19.625432, Elapsed iterations: 73116
# Sentiment index is: Q_aggscore2_SD, Parameters are: [3, 1, 1, 0], Elapsed time: 1 day, 14:36:42.433823, Elapsed iterations: 75824
# Sentiment index is: Q_aggscore2_SD, Parameters are: [3, 1, 1, 1], Elapsed time: 1 day, 15:58:08.162811, Elapsed iterations: 78532
# Sentiment index is: Q_aggscore2_SD4, Parameters are: [3, 1, 0, 1], Elapsed time: 1 day, 17:19:34.303603, Elapsed iterations: 81240
# Sentiment index is: Q_aggscore2_SD4, Parameters are: [1, 2, 0, 1], Elapsed time: 1 day, 18:41:04.235000, Elapsed iterations: 83948
# Sentiment index is: Q_aggscore2_SD4, Parameters are: [1, 2, 1, 0], Elapsed time: 1 day, 20:02:39.110208, Elapsed iterations: 86656
# Sentiment index is: Q_aggscore2_SD4, Parameters are: [3, 1, 1, 0], Elapsed time: 1 day, 21:24:13.155813, Elapsed iterations: 89364
# Sentiment index is: Q_aggscore2_SD4, Parameters are: [3, 1, 1, 1], Elapsed time: 1 day, 22:45:46.476816, Elapsed iterations: 92072
# Total Time: 2 days, 0:07:21.649826, # of iterations: 94780

# %% [markdown]
# ## Results
# The results dataframe shows, per sentiment index and parameters, what was the performance (relating to the buying every stock in the beginning of the period and selling it on the last day of the period) and the success ratio of each position taken. The success ratio is defined whether the specific position had a positive return.
# <br>From looking at the top performing parameters and sentiments, it can be seen that:
# - Using the sentiment data improves the results, both on the "performance" and the "ratio" indicators.
# - Adding another condition to enter and exit a position results in much less positions but leads to better performance and much better success ratio.
# - Using time based sentiment indices (such as SD and SD4) improves both performance and success ratio compared to a single timeframe sentiment.
#
# ## Conclusion
# #### This project has shown that adding a sentiment to a purely technical analysis may improve results.
# Although the best performing indicators have supplied us with at most 50% success over the market performance, it can be a result of lacking Technical Analysis indicators. However, given better performing technical analysis technique and/or indicators, we saw that using sentiment analysis <b>can possibly</b> improve result compared to baseline performance.
# The fact that our best perfomance indicators have managed to get a success ratio of above 60% shows that the rational behind entering positions was solid, but not enough positions were opened, resulting in only 50% performance compared to the market. It can also be possible given better indicators for entering to a position. The fact that a portfolio-based approach wasn't taken, and that positions can only be opened or closed (hence, cannot be expanded or narrowed) possibly minimized that possible return out of successful signals, given a success rate of above 50%.

# %% [markdown]
# ### Results by success ratio

# %%
results.sort_values("ratio",ascending=False)
# Out:
#           sentiment        params  performance  positions  successfull  \
# 32  Q_aggscore2_SD4  [1, 2, 1, 0]     0.487164       3945         2533
# 22  Q_aggscore1_SD4  [1, 2, 1, 0]     0.487254       3941         2527
# 31  Q_aggscore2_SD4  [1, 2, 0, 1]     0.485497       3940         2519
# 24  Q_aggscore1_SD4  [3, 1, 1, 1]     0.501977       5830         3727
# 34  Q_aggscore2_SD4  [3, 1, 1, 1]     0.501083       5841         3729
# 21  Q_aggscore1_SD4  [1, 2, 0, 1]     0.485110       3942         2516
# 23  Q_aggscore1_SD4  [3, 1, 1, 0]     0.500278       5874         3707
# 33  Q_aggscore2_SD4  [3, 1, 1, 0]     0.498997       5893         3709
# 20  Q_aggscore1_SD4  [3, 1, 0, 1]     0.500841       5877         3693
# 30  Q_aggscore2_SD4  [3, 1, 0, 1]     0.500001       5888         3695
# 26   Q_aggscore2_SD  [1, 2, 0, 1]     0.463242       5549         3302
# 16   Q_aggscore1_SD  [1, 2, 0, 1]     0.462927       5542         3290
# 19   Q_aggscore1_SD  [3, 1, 1, 1]     0.489906       8887         5258
# 25   Q_aggscore2_SD  [3, 1, 0, 1]     0.481976       8995         5318
# 15   Q_aggscore1_SD  [3, 1, 0, 1]     0.482036       8977         5306
# 29   Q_aggscore2_SD  [3, 1, 1, 1]     0.490007       8897         5250
# 17   Q_aggscore1_SD  [1, 2, 1, 0]     0.461978       5555         3275
# 18   Q_aggscore1_SD  [3, 1, 1, 0]     0.483289       8975         5284
# 27   Q_aggscore2_SD  [1, 2, 1, 0]     0.461995       5559         3271
# 28   Q_aggscore2_SD  [3, 1, 1, 0]     0.487842       8994         5281
# 14      Q_aggscore2  [3, 1, 1, 1]     0.413412       2526         1446
# 9       Q_aggscore1  [3, 1, 1, 1]     0.414507       2538         1447
# 12      Q_aggscore2  [1, 2, 1, 0]     0.419521       1953         1104
# 7       Q_aggscore1  [1, 2, 1, 0]     0.417370       1957         1101
# 8       Q_aggscore1  [3, 1, 1, 0]     0.411909       2583         1453
# 5       Q_aggscore1  [3, 1, 0, 1]     0.413831       2562         1441
# 10      Q_aggscore2  [3, 1, 0, 1]     0.414554       2547         1431
# 13      Q_aggscore2  [3, 1, 1, 0]     0.411199       2557         1436
# 11      Q_aggscore2  [1, 2, 0, 1]     0.416860       1937         1081
# 6       Q_aggscore1  [1, 2, 0, 1]     0.416360       1937         1075
# 0              None  [3, 1, 0, 1]     0.410734      73144        33632
# 1              None  [1, 2, 0, 1]     0.422855      35209        16044
# 4              None  [3, 1, 1, 1]     0.403787      61543        24851
# 2              None  [1, 2, 1, 0]     0.423721      34733        13719
# 3              None  [3, 1, 1, 0]     0.395773      61818        24163
#
#               time     ratio
# 32 01:21:34.045605  0.642079
# 22 01:21:17.650174  0.641208
# 31 01:21:34.875208  0.639340
# 24 01:21:20.654384  0.639280
# 34 01:21:35.173010  0.638418
# 21 01:21:26.015992  0.638255
# 23 01:21:17.053774  0.631086
# 33 01:21:33.321003  0.629391
# 20 01:21:12.964567  0.628382
# 30 01:21:29.931397  0.627548
# 26 01:21:21.862384  0.595062
# 16 01:21:06.690157  0.593649
# 19 01:21:09.325161  0.591651
# 25 01:21:22.074979  0.591217
# 15 01:21:14.144768  0.591066
# 29 01:21:26.140792  0.590087
# 17 01:21:09.884158  0.589559
# 18 01:21:11.622766  0.588747
# 27 01:21:22.808391  0.588415
# 28 01:21:25.728988  0.587169
# 14 01:21:08.664356  0.572447
# 9  01:22:04.740642  0.570134
# 12 01:21:06.592557  0.565284
# 7  01:21:17.097975  0.562596
# 8  01:21:04.603150  0.562524
# 5  01:20:58.951138  0.562451
# 10 01:21:29.470796  0.561837
# 13 02:21:08.714359  0.561596
# 11 01:21:02.714146  0.558080
# 6  01:20:58.321141  0.554982
# 0  01:17:33.949182  0.459805
# 1  01:17:28.775974  0.455679
# 4  01:17:35.428982  0.403799
# 2  01:17:29.934777  0.394985
# 3  01:17:36.808983  0.390873

# %% [markdown]
# ### Results by performance

# %%
results.sort_values("performance",ascending=False)
# Out:
#           sentiment        params  performance  positions  successfull  \
# 24  Q_aggscore1_SD4  [3, 1, 1, 1]     0.501977       5830         3727
# 34  Q_aggscore2_SD4  [3, 1, 1, 1]     0.501083       5841         3729
# 20  Q_aggscore1_SD4  [3, 1, 0, 1]     0.500841       5877         3693
# 23  Q_aggscore1_SD4  [3, 1, 1, 0]     0.500278       5874         3707
# 30  Q_aggscore2_SD4  [3, 1, 0, 1]     0.500001       5888         3695
# 33  Q_aggscore2_SD4  [3, 1, 1, 0]     0.498997       5893         3709
# 29   Q_aggscore2_SD  [3, 1, 1, 1]     0.490007       8897         5250
# 19   Q_aggscore1_SD  [3, 1, 1, 1]     0.489906       8887         5258
# 28   Q_aggscore2_SD  [3, 1, 1, 0]     0.487842       8994         5281
# 22  Q_aggscore1_SD4  [1, 2, 1, 0]     0.487254       3941         2527
# 32  Q_aggscore2_SD4  [1, 2, 1, 0]     0.487164       3945         2533
# 31  Q_aggscore2_SD4  [1, 2, 0, 1]     0.485497       3940         2519
# 21  Q_aggscore1_SD4  [1, 2, 0, 1]     0.485110       3942         2516
# 18   Q_aggscore1_SD  [3, 1, 1, 0]     0.483289       8975         5284
# 15   Q_aggscore1_SD  [3, 1, 0, 1]     0.482036       8977         5306
# 25   Q_aggscore2_SD  [3, 1, 0, 1]     0.481976       8995         5318
# 26   Q_aggscore2_SD  [1, 2, 0, 1]     0.463242       5549         3302
# 16   Q_aggscore1_SD  [1, 2, 0, 1]     0.462927       5542         3290
# 27   Q_aggscore2_SD  [1, 2, 1, 0]     0.461995       5559         3271
# 17   Q_aggscore1_SD  [1, 2, 1, 0]     0.461978       5555         3275
# 2              None  [1, 2, 1, 0]     0.423721      34733        13719
# 1              None  [1, 2, 0, 1]     0.422855      35209        16044
# 12      Q_aggscore2  [1, 2, 1, 0]     0.419521       1953         1104
# 7       Q_aggscore1  [1, 2, 1, 0]     0.417370       1957         1101
# 11      Q_aggscore2  [1, 2, 0, 1]     0.416860       1937         1081
# 6       Q_aggscore1  [1, 2, 0, 1]     0.416360       1937         1075
# 10      Q_aggscore2  [3, 1, 0, 1]     0.414554       2547         1431
# 9       Q_aggscore1  [3, 1, 1, 1]     0.414507       2538         1447
# 5       Q_aggscore1  [3, 1, 0, 1]     0.413831       2562         1441
# 14      Q_aggscore2  [3, 1, 1, 1]     0.413412       2526         1446
# 8       Q_aggscore1  [3, 1, 1, 0]     0.411909       2583         1453
# 13      Q_aggscore2  [3, 1, 1, 0]     0.411199       2557         1436
# 0              None  [3, 1, 0, 1]     0.410734      73144        33632
# 4              None  [3, 1, 1, 1]     0.403787      61543        24851
# 3              None  [3, 1, 1, 0]     0.395773      61818        24163
#
#               time     ratio
# 24 01:21:20.654384  0.639280
# 34 01:21:35.173010  0.638418
# 20 01:21:12.964567  0.628382
# 23 01:21:17.053774  0.631086
# 30 01:21:29.931397  0.627548
# 33 01:21:33.321003  0.629391
# 29 01:21:26.140792  0.590087
# 19 01:21:09.325161  0.591651
# 28 01:21:25.728988  0.587169
# 22 01:21:17.650174  0.641208
# 32 01:21:34.045605  0.642079
# 31 01:21:34.875208  0.639340
# 21 01:21:26.015992  0.638255
# 18 01:21:11.622766  0.588747
# 15 01:21:14.144768  0.591066
# 25 01:21:22.074979  0.591217
# 26 01:21:21.862384  0.595062
# 16 01:21:06.690157  0.593649
# 27 01:21:22.808391  0.588415
# 17 01:21:09.884158  0.589559
# 2  01:17:29.934777  0.394985
# 1  01:17:28.775974  0.455679
# 12 01:21:06.592557  0.565284
# 7  01:21:17.097975  0.562596
# 11 01:21:02.714146  0.558080
# 6  01:20:58.321141  0.554982
# 10 01:21:29.470796  0.561837
# 9  01:22:04.740642  0.570134
# 5  01:20:58.951138  0.562451
# 14 01:21:08.664356  0.572447
# 8  01:21:04.603150  0.562524
# 13 02:21:08.714359  0.561596
# 0  01:17:33.949182  0.459805
# 4  01:17:35.428982  0.403799
# 3  01:17:36.808983  0.390873
